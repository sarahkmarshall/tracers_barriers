# %% [markdown]
# # Tracers and barriers paper
#
# Tracers and Barriers paper
#
# This script is for the generation of flow model input files, running the flow model, and the generation of transport model input files & running the transport model.
#
# THEN --> post-process the data using the post-processing (tracers_barriers_PP.py) script.
#
# ## Case Study (CS) & recharge descriptions
#
# CS1 is with no barrier.
# CS2 is fully-penetrating barrier.
# CS3 is buried barrier.
#
# Recharge 1 = Diffuse recharge across the whole aquifer.
# Recharge 2 = Upgradient (mountain-front) recharge only.

# %% [markdown]
# ## Importing packages

# %%
import datetime
from decimal import Decimal
import flopy
from flopy import mt3d
import flopy.utils.binaryfile as bf
import numpy as np
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import ticker
import os
import pandas as pd
from scipy.ndimage.filters import gaussian_filter
import subprocess
import sys
import time


print(sys.version)
print('numpy version: {}'.format(np.__version__))
print('matplotlib version: {}'.format(mpl.__version__))
print('pandas version: {}'.format(pd.__version__))
print('flopy version: {}'.format(flopy.__version__))
# Out:
# flopy is installed in C:\Program Files\Anaconda3\lib\site-packages\flopy
# 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]
# numpy version: 1.18.1
# matplotlib version: 3.1.3
# pandas version: 1.0.2
# flopy version: 3.3.0

# %% [markdown]
# ## Setting up directories

# %%
project_folder      = os.getcwd()
print("Project folder is: %s" %project_folder)
    
dataDirectory = os.path.join(project_folder, "Data")
if not os.path.exists(dataDirectory):
    os.makedirs(dataDirectory)
    
print("The data directory is: %s" %dataDirectory)

figureDirectory = os.path.join(project_folder, "Figures")
if not os.path.exists(figureDirectory):
    os.makedirs(figureDirectory)

print("Directory to save figures: %s" %figureDirectory)
# Out:
# Project folder is: C:\workspace\tracers_barriers\tracers_barriers
# The data directory is: C:\workspace\tracers_barriers\tracers_barriers\Data
# Directory to save figures: C:\workspace\tracers_barriers\tracers_barriers\Figures

# %%
modelName           = "TB_01"
modelName_mt3d      = "%s_mt3d"%modelName

# %%
print("Flow model name is: %s, transport model name is: %s" %(modelName, modelName_mt3d))
# Out:
# Flow model name is: TB_01, transport model name is: TB_01_mt3d

# %%
MODFLOW_folder      = 'MODFLOW-NWT_64.exe'

project_folder      = os.getcwd()
MT3D_USGS_folder    = 'MT3D-USGS_64.exe'
mt3d_version        = 'mt3d-usgs' 
model_precision     = 'single' # 'double'

# %% [markdown]
# ## Model discretisation

# %%
nlay = 12                    # Number of layers.
Lx = 10000.                  # Length of the model sides in metres.
Ly = 5000                    # Rectangular domain.
delr = 50.                   # Spacing length across rows in metres.
delc = delr                  # The spacing along columns and rows are equal.
ncol = int(Lx/delr)          # Number of columns.
nrow = int(Ly/delc)          # Number of rows.
ncells = nlay*ncol*nrow      # Total number of cells in the model.
ncells_per_layer = ncol*nrow # Number of cells per layer.
surface_area = Lx*Ly         # m^2

ztop = 300.                  # Top of model.
zbot = 0.                    # Base of model.
delv = (ztop - zbot) / nlay  # Length of cells in z direction.
botm = np.linspace(ztop, zbot, nlay + 1) 

print("Number of layers: %i, rows: %i, columns: %i" %(nlay, nrow, ncol))
print("Total number of cells: %i" %ncells)
# Out:
# Number of layers: 12, rows: 100, columns: 200
# Total number of cells: 240000

# %% [markdown]
# # Set up figure properties

# %%
# Set up the extent for the plotting

extent = (delr/2., 
          Lx - delr/2., 
          delc/2., 
          Ly - delc/2.)

plt_lyr = nlay-1
row_cross_section = int(nrow/2)

fontSize = 14

def cm2inch(value):
    return value/2.54
    
mpl.rc("axes", lw=0.5, edgecolor='grey', labelsize=fontSize)
mpl.rc('lines', lw=1, c='k')
mpl.rc('font', size=fontSize)
mpl.rc('legend', labelspacing=0.1, frameon=False, fontsize=fontSize)
mpl.rc("figure", figsize=(cm2inch(8.25), cm2inch(8.25*1.25)), titlesize='medium')
mpl.rc('font',family='Arial')

colormap_options = ["gist_ncar", "RdGy_r", "gist_stern", "hsv", 
                    "nipy_spectral", 'gist_rainbow', "seismic",
                    "PiYG_r", "PuOr", "Spectral"]

contour_colors = "k"
velocity_arrows_color = "white"

head_cmap = 'coolwarm'
age_cmap = 'jet'

diff_head_cmap = colormap_options[7]
diff_age_cmap = colormap_options[6]

gamma_cmap = colormap_options[6] 
hk_array_cmap = 'Greys_r'
recharge_cmap = 'Blues'

horizontal_colour = "darkcyan"
buried_colour = "firebrick"

### Velocity arrow parameters

iskipCols = 75
iskipLayers = 2
iskipRows = 10
layerDisMultiplyer = 20
colDisMultiplyer = .8
rowDisMultiplyer = .5

## Max and min head and age for plots --> because I want them all to be 
# directly comparable, i.e. to have exactly the same colourbars

age_min = 0
age_max = 21000

head_min = 290.0
head_max = 296.0

gamma_age_min = -1.6 
gamma_age_max = 1.6

# Contour labels 

gamma_cs_labels = [-2, -1.5, -1, -0.5, 0, 0.5, 1, 1.5, 2]
levels = np.arange(0, 20000, 5000)   # Plotting contour set
levels_2 = np.arange(0, 20000, 2500) # Plotting contour set

# Some of the contours I want to have manual plotting, but this is annoying when I
# 'm playing around with them so I can change some of them here

manual_plot = False# True/False

dpi_value = 600

# %% [markdown]
# ## Hydraulic properties

# %%
sHead = 290                  # Starting head across aquifer.

sy = 0.1                     # Specific yield.
ss = sy/ztop                 # Specific storage.
laytyp = 1                   # Layer type (1 = convertible; 0 = confined).

hk_aquifer = 1.              # Hydraulic conductvity along rows (m/day).
vka = hk_aquifer/10.         # Vertical hydraulic conductivity.

prsity = sy
tortuosity_factor = 0.09

recharge_flux = 1.3699e-5    # m/d This is equivalent to 5 mm per year.
total_recharge = recharge_flux*surface_area # m^3 per day.
total_recharge_per_y = total_recharge*365.25 # m^3 per year.

length_simulation = 1        # Length of the steady-state flow model (days).

# %% [markdown]
# ## Barrier characteristics
#
# This is mostly for scenarios  where barrier is orthogonal to principle groundwater flow direction (need extra in cases with angled barrier).

# %%
hk_barrier           = hk_aquifer/1000 # m/d 3 orders of magnitude lower than the aquifer.
barrier_width        = 50 # m
number_barrier_cols  = barrier_width/delr  # So we can test/change the grid spacing.
print("Number of barrier columns: %i" %number_barrier_cols)
column_of_barrier    = []

if number_barrier_cols == 1:
    column_of_barrier.append(int(ncol/2)) 
elif number_barrier_cols%2 == 0: # Even number
    for i in range(int(number_barrier_cols/2)):
        a = int(number_barrier_cols/2) - i
        column_of_barrier.append(int(ncol/2)-a)

    for i in range(int(number_barrier_cols/2)):
        print(i)
        column_of_barrier.append(int(ncol/2)+i)
else: # Odd number        
    for i in range(int(number_barrier_cols/2)):
        a = int(number_barrier_cols/2) - i
        column_of_barrier.append(int(ncol/2)-a)

    for i in range(int(number_barrier_cols/2)):
        print(i)
        column_of_barrier.append(int(ncol/2)+i)

    column_of_barrier.append(int(ncol/2)+int(number_barrier_cols/2))
    
percentage_gap        = 10 # CS2 
first_row_barr        = int(nrow/percentage_gap) # CS2 
last_row_barr         = int(nrow-(nrow/percentage_gap)) # CS2 
start_lay_barr        = int(nlay/2) # CS3
end_lay_barr          = nlay # CS3


middle_of_barrier = ncol/2
vol_barr_fullypen = 50*4000*300  
vol_barr_buried = 50*5000*150

sa_barr_fullypen = 50*4000 # m2
sa_barr_buried = 50*5000 # m2

xsectn_area_fp = 4000*300 # m2
xsectn_area_bu = 5000*150 # m2

len_barr_fullypen = 4000
len_barr_buried = 5000
# Out:
# Number of barrier columns: 1

# %% [markdown]
# ## Barrier characteristics - angled barrier
#
# Calculate the nrow and ncol for the barriers with an angle. Note the coarser the grid size, the less likely length will still equal 4000 m.
#
# I am not sure if this script will work if `delr` $\neq$ `delc`.

# %% [markdown]
# ### First step - define a function that will determine the number of rows and columns based on the angle.
#
# This is the basic trigonometry:
#
# ![title](image.png)

# %%
def make_angl_barr_row_cols(angle):

    print("Angle: % 2.2f" % angle)

    barr_len = len_barr_fullypen
    barr_len_across_rows = barr_len*math.cos(math.radians(angle))
    print("Barrier len across rows: %2.2f m" %barr_len_across_rows)
    barr_len_across_cols = barr_len*math.sin(math.radians(angle))
    print("Barrier len across cols: %2.2f m" %barr_len_across_cols)

    nrow_b = barr_len_across_rows/delc
    print("Number of angled barrier rows: %i" % nrow_b)
    ncol_b = barr_len_across_cols/delr
    print("Number of angled barrier cols: %i" % ncol_b)

    first_row_b = int(0+(nrow - nrow_b)/2) 
    last_row_b = int(nrow-(nrow - nrow_b)/2) 
    len_row_b = last_row_b - first_row_b 
    barr_rows_b = np.linspace(first_row_b, last_row_b, len_row_b+1)
    
    first_col_b = int((ncol/2) - (ncol_b/2))
    last_col_b = int((ncol/2) + (ncol_b/2))
    len_col_b = last_col_b - first_col_b
    barr_cols_b = np.linspace(first_col_b, last_col_b, len_col_b+1)
    
    if len(barr_rows_b) > len(barr_cols_b): 
        ratio_b = len(barr_rows_b)/len(barr_cols_b)
        dir_b = 1
        longer_len = len_row_b
        barr_rows_b = np.linspace(first_row_b, last_row_b, len_row_b+1) 
        
    elif len(barr_rows_b) == len(barr_cols_b):
        print("No changes reqd - barrier 45 degr starting rows and cols suffice")
        dir_b = 99

    else:
        ratio_b = len(barr_cols_b)/len(barr_rows_b)
        dir_b = 2
        longer_len = len_col_b 
        barr_cols_b = np.linspace(first_col_b, last_col_b, len_col_b+1)

    cols_list = []
    rows_list = []

    if dir_b == 1:    # This means that there are more rows than barriers
        for i in range(len(barr_rows_b)):
            if i % 2 == 0:
                for n in range(int(ratio_b)):
                    cols_list.append(first_col_b+i)
            else:
                for n in range(int(ratio_b+1)):
                    cols_list.append(first_col_b+i)
            barr_cols_b = cols_list[:len(barr_rows_b)]
    elif dir_b == 99:
        print("Barrier 45 degrees no update")
        
    else: # I.e. there are more columns than rows
        for i in range(len(barr_cols_b)):
            if i % 2 == 0:
                for n in range(int(ratio_b)):
                    rows_list.append(first_row_b+i)
            else:
                for n in range(int(ratio_b+1)):
                    rows_list.append(first_row_b+i)
            barr_rows_b = rows_list[:len(barr_cols_b)]

    if len(barr_cols_b) == len(barr_rows_b):
        print("Length of rows and columns of barrier are equal")
        length_barr_cells = len(barr_cols_b)
    else:
        print("Rows and columns for barrier aren't equal, you have a problem")

    #----------------------------------------
    ### Make a list of the columns the barrier is in

    #How many columns does the barrier need to be? 
    #Make sure the barrier is the correct thickness (when cell size is < barrier width).

    #This is the same for all case studies. 

    barrier_width = 50 # m
    number_barrier_cols = barrier_width/delr

    barrier_width = 50 # m
    number_barrier_cols = barrier_width/delr

    cols_barrs_list = []

    if number_barrier_cols == 1:
        cols_barrs_list.append(barr_cols_b) 

    elif number_barrier_cols%2 == 0: # Even number
        for i in range(int(number_barrier_cols/2)):
            a = int(number_barrier_cols/2) - i
            cols_barrs_list.append(np.asarray(barr_cols_b)-a)

        for i in range(int(number_barrier_cols/2)):
            print(i)
            cols_barrs_list.append(np.asarray(barr_cols_b)+i)

    else: # Odd number        
        for i in range(int(number_barrier_cols/2)):
            a = int(number_barrier_cols/2) - i
            cols_barrs_list.append(np.asarray(barr_cols_b)-a)

        for i in range(int(number_barrier_cols/2)):
            print(i)
            cols_barrs_list.append(np.asarray(barr_cols_b)+i)

        cols_barrs_list.append(np.asarray(barr_cols_b)+int(number_barrier_cols/2))

    return length_barr_cells, cols_barrs_list, barr_rows_b

# %% [markdown]
# ## Making the hydraulic conductivity arrays

# %%
number_of_casestudies = 3

# %% [markdown]
# ### Case Study 0: No barrier

# %%
hk_array_1 = hk_aquifer * np.ones((nlay, nrow, ncol), dtype=np.float32)

# %% [markdown]
# ### Case Study 1: Fully-penetrating barrier

# %%
hk_array_2 = hk_aquifer * np.ones((nlay, nrow, ncol), dtype=np.float32)     
  
for il in range(nlay):
    for ir in range(first_row_barr, last_row_barr, 1): 
        for col_number in range(len(column_of_barrier)):
            hk_array_2[il, ir, column_of_barrier[col_number]] = hk_barrier

# %% [markdown]
# ### Case Study 2: Buried barrier

# %%
hk_array_3 = hk_aquifer * np.ones((nlay, nrow, ncol), dtype=np.float32)     

for il in range(start_lay_barr, end_lay_barr):
    for ir in range(nrow): 
        for col_number in range(len(column_of_barrier)):
            hk_array_3[il, ir, column_of_barrier[col_number]] = hk_barrier

# %% [markdown]
# ### Case study 3: Angled barriers
#
# Here I am using a function to create the HK array so it can be easily iterated over to generate each hk array for each angle.

# %%
def makeAngledHKArray(length_barr_cells, cols_barrs_list, barr_rows_b):

    hk_array_4_b = hk_aquifer * np.ones((nlay, nrow, ncol), dtype=np.float32)     

    for il in range(nlay):
        for i in range(length_barr_cells):
            for col_width_no in range(len(cols_barrs_list)):
                hk_array_4_b[il, int(barr_rows_b[i]), int(cols_barrs_list[col_width_no][i])] = hk_barrier 

    hk_array_4 = hk_array_4_b     
    
    return hk_array_4

# %% [markdown]
# Now apply this function with the correct barrier characteristics for each angle

# %%
angles = [11.25, 22.5, 33.75, 45, 56.25, 67.5, 78.75, 90]
hk_arrays_angled = []

for angle_i in range(len(angles)):
    angle = angles[angle_i]

    length_barr_cells, cols_barrs_list, barr_rows_b = make_angl_barr_row_cols(angle)
    
    
    hk_array_4 = makeAngledHKArray(length_barr_cells, cols_barrs_list, barr_rows_b)
    
    hk_arrays_angled.append(hk_array_4)   
    print("Angled array has been saved to the list")
    
print("Length of list with angled hk arrays: %i" %len(hk_arrays_angled))
# Out:
# Angle:  11.25
# Barrier len across rows: 3923.14 m
# Barrier len across cols: 780.36 m
# Number of angled barrier rows: 78
# Number of angled barrier cols: 15
# Length of rows and columns of barrier are equal
# Angled array has been saved to the list
# Angle:  22.50
# Barrier len across rows: 3695.52 m
# Barrier len across cols: 1530.73 m
# Number of angled barrier rows: 73
# Number of angled barrier cols: 30
# Length of rows and columns of barrier are equal
# Angled array has been saved to the list
# Angle:  33.75
# Barrier len across rows: 3325.88 m
# Barrier len across cols: 2222.28 m
# Number of angled barrier rows: 66
# Number of angled barrier cols: 44
# Length of rows and columns of barrier are equal
# Angled array has been saved to the list
# Angle:  45.00
# Barrier len across rows: 2828.43 m
# Barrier len across cols: 2828.43 m
# Number of angled barrier rows: 56
# Number of angled barrier cols: 56
# No changes reqd - barrier 45 degr starting rows and cols suffice
# Barrier 45 degrees no update
# Length of rows and columns of barrier are equal
# Angled array has been saved to the list
# Angle:  56.25
# Barrier len across rows: 2222.28 m
# Barrier len across cols: 3325.88 m
# Number of angled barrier rows: 44
# Number of angled barrier cols: 66
# Length of rows and columns of barrier are equal
# Angled array has been saved to the list
# Angle:  67.50
# Barrier len across rows: 1530.73 m
# Barrier len across cols: 3695.52 m
# Number of angled barrier rows: 30
# Number of angled barrier cols: 73
# Length of rows and columns of barrier are equal
# Angled array has been saved to the list
# Angle:  78.75
# Barrier len across rows: 780.36 m
# Barrier len across cols: 3923.14 m
# Number of angled barrier rows: 15
# Number of angled barrier cols: 78
# Length of rows and columns of barrier are equal
# Angled array has been saved to the list
# Angle:  90.00
# Barrier len across rows: 0.00 m
# Barrier len across cols: 4000.00 m
# Number of angled barrier rows: 0
# Number of angled barrier cols: 80
# Length of rows and columns of barrier are equal
# Angled array has been saved to the list
# Length of list with angled hk arrays: 8

# %% [markdown]
# ### Plot the different hydraulic conductivity vectors
#
# These are for the case where the barrier is oriented orthogonal to the principle groundwater flow direction.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3,1,figsize=(12,10))

ax1.imshow(np.flipud(hk_array_1[plt_lyr, :, :]), extent=extent, 
           vmin=hk_barrier, vmax=hk_aquifer, cmap=hk_array_cmap) 
ax1.get_xaxis().set_visible(False)
ax1.set_ylabel("$y$ [m]")

ax2.imshow(np.flipud(hk_array_2[plt_lyr, :, :]), extent=extent, 
           vmin=hk_barrier, vmax=hk_aquifer, cmap=hk_array_cmap) 
ax2.get_xaxis().set_visible(False)

ax2.set_ylabel("$y$ [m]")

ax3.imshow(np.flipud(hk_array_3[plt_lyr, :, :]), extent=extent, 
           vmin=hk_barrier, vmax=hk_aquifer, cmap=hk_array_cmap) 

ax3.set_ylabel("$y$ [m]")
ax3.set_xlabel("$x$ [m]")

ax1.set_title('Case Study 0 - no barrier (layer %i)' %plt_lyr)
ax2.set_title('Case Study 1 - Fully Penetrating barrier (layer %i)' %plt_lyr)
ax3.set_title('Case Study 2 - Buried barrier (layer %i)' %plt_lyr)

plt.tight_layout()

# %% [markdown]
# ## Plot the angled hydraulic conductivity arrays

# %%
fig = plt.figure(figsize=(12,10))

pltcount=1
for angle_i in range(len(angles)):
    ax = plt.subplot(int(len(angles)/2), 2, pltcount)
    
    ax.imshow(np.flipud(hk_arrays_angled[angle_i][plt_lyr, :, :]), extent=extent, 
           vmin=hk_barrier, vmax=hk_aquifer, cmap=hk_array_cmap)
    
    ax.set_title('HK array angle: %2.2f (layer %i)' % (angles[angle_i], plt_lyr))

    if pltcount == int(len(angles)-1) or pltcount == int(len(angles)):
        pass
    else:
        ax.get_xaxis().set_visible(False)
    
    pltcount = pltcount+1

# %% [markdown]
# ## Recharge characteristics

# %%
number_of_recharge_scenarios = 2

# %% [markdown]
# Recharge array 1 = diffuse recharge across the whole aquifer in equal amounts.

# %%
recharge_array_1 = recharge_flux * np.ones((nrow, ncol), dtype=np.float32)

# %% [markdown]
# Recharge array 2 = recharge across only the top of the catchment.
# Recharge across all rows, across first 50 columns (One quarter of catchment).

# %%
n_cols_rech_2    = int(ncol/4)
n_cells_rech_2   = int(n_cols_rech_2*nrow)
SA_recharge_2    = Ly*n_cols_rech_2*delc # Surface area (m^2)
recharge_flux_2  = total_recharge/SA_recharge_2 # m/d

recharge_array_2 = np.zeros((nrow, ncol), dtype=np.float32)

for c in range(n_cols_rech_2):  # Applying recharge to every row to the columns specified.
    for r in range(nrow): 
        recharge_array_2[r, c] = recharge_flux_2

# %% [markdown]
# ### Plot the recharge arrays
#
# First I am going to change the units for recharge (just for the plots, not in the models.

# %%
# Change units for the plot
conv_fact = 1000*365
recharge_ar_1_mday = np.copy(recharge_array_1)*conv_fact
recharge_ar_2_mday = np.copy(recharge_array_2)*conv_fact
rech_flux_mday = recharge_flux*conv_fact

# Now make the plots
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(6,5))

img1 = ax1.imshow(np.flipud(recharge_ar_1_mday[:, :]), extent=extent, 
           vmin=0, vmax=rech_flux_mday, cmap=recharge_cmap) 
ax1.get_xaxis().set_visible(False)
ax1.set_ylabel("$y$ [m]")

img2 = ax2.imshow(np.flipud(recharge_ar_2_mday[:, :]), extent=extent, 
           vmin=0, vmax=rech_flux_mday, cmap=recharge_cmap) 
ax2.get_xaxis().set_visible(False)

ax2.set_ylabel("$y$ [m]")
ax1.set_xlabel("$x$ [m]")

ax1.set_title('Recharge scenario 0 - diffuse')
ax2.set_title('Recharge scenario 1 - upgradient')

cbaxes1 = fig.add_axes([0.85, 0.25, 0.02, 0.5]) 
cb1 = plt.colorbar(img1, cax = cbaxes1, orientation="vertical")  
cb1.set_label('Recharge flux [mm/y]')

# %% [markdown]
# ## Boundary conditions

# %% [markdown]
# General head boundary on the right-hand side.
# No boundary on the left-hand side so use default condition which is a no-flow boundary.

# %%
stageleft  = float(sHead)
stageright = float(sHead)

bound_sp1  = []
for il in range(nlay):

    condright = (hk_aquifer * (stageright - zbot) * delc)/10

    for ir in range(nrow):
        bound_sp1.append([il, ir, ncol - 1, stageright, condright])

print('Adding ', len(bound_sp1), 'GHBs for stress period 1.')

ghb_spd = {0: bound_sp1}
# Out:
# Adding  1200 GHBs for stress period 1.

# %% [markdown]
# Specifying starting heads

# %%
if nlay == 1:
    ibound = np.ones((nrow, ncol), dtype=np.int32)
    strt = sHead * np.ones((nrow, ncol), dtype=np.float32)

else:
    ibound = np.ones((nlay, nrow, ncol), dtype=np.int32)
    strt = sHead * np.ones((nlay, nrow, ncol), dtype=np.float32)

# %% [markdown]
# ### Plot the model set up

# %%
plt.figure(figsize=(8, 6))
ax = plt.subplot(1, 1, 1)   

ax.imshow(np.flipud(hk_array_3[plt_lyr, :, :]), extent=extent, 
           vmin=hk_barrier, vmax=hk_aquifer, cmap=hk_array_cmap) 

ax.plot([-1,-1], [-5,-5], c="r", lw=10, label="No flow boundary")
ax.plot([-1,-1], [-5,-5], c="orange", lw=10, label="General head boundary")
ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

plt.grid()

plt.xlabel("$x$ [m]", fontsize = 14)
plt.ylabel("$y$ [m]", fontsize = 14)

ax.axvline(x=0, ymin=0, ymax=1, lw=10, color="r") 
ax.axvline(x=Lx, ymin=0, ymax=1, lw=10, color="orange")

plt.xlim([0, Lx])
plt.ylim([0, Ly])

plt.arrow(500, 2500, 2000, 0, color="dodgerblue", ls="-", lw=1, head_width=300, 
          overhang=.1, length_includes_head=True)

plt.legend(frameon=False)

ax.set_title('Model set up plan view for Fully Penetrating Barrier')
# Out:
# Text(0.5, 1.0, 'Model set up plan view for Fully Penetrating Barrier')

# %% [markdown]
# ## Stress periods

# %% [markdown]
# 1 Stress period: steady state only

# %%
nper   = 1 # Number of model stress periods.
perlen = [length_simulation] 

nstp   = [1] # Number of time steps in each stress period.
tsmult = [1]
steady = [True] # True = steady state.

print("One steady-state stress periods set up")
# Out:
# One steady-state stress periods set up

# %% [markdown]
# ## Input files and running flow model
#
# Running multiple model scenarios:
#
# * 1st:   Different recharge scenarios.
#
# * 2nd:   Different case studies, representing the different hydraulic conductivities (barrier configurations).

# %%
print("The total number of scenarios is: %s" %(
                        number_of_recharge_scenarios*number_of_casestudies))
# Out:
# The total number of scenarios is: 6

# %% [markdown]
# ## Function to set up and run the flow model
#
# Need to be careful whether I am adding 1 to recharge scenario and case study or not, I have changed things around a bit.

# %%
print(modelName_mt3d)
# Out:
# TB_01_mt3d

# %%
def flow_model(rechargeScenario, caseStudy):
    
    modelname = str(modelName) + "_R" + str(rechargeScenario) + "_CS" + str(caseStudy)
    print("Flow model name: " + str(modelname))
        
    modelname_mt3d = modelName_mt3d + "_R" + str(rechargeScenario) + "_CS" + str(caseStudy)
    print("Transport model name: " + str(modelname_mt3d))
    
    mf = flopy.modflow.Modflow(modelname, exe_name=MODFLOW_folder, version='mfnwt') # MODFLOW-NWT
    
    dis = flopy.modflow.ModflowDis(mf, nlay, nrow, ncol, delr=delr, 
                                        delc=delc,top=ztop, botm=botm[1:],
                                        tsmult = tsmult, nper=nper, perlen=perlen, 
                                        nstp=nstp, steady=steady)
        
    print("Discretisation module set up")
       
    # Which hydraulic conductivity array do I use, depending on which scenario is applied:
        
    if caseStudy == 0:
        hk_array = hk_array_1
        print("Setting up hk array for Case Study 0")
            
    elif caseStudy == 1:
        hk_array = hk_array_2
        print("Setting up hk array for Case Study 1")
                   
    elif caseStudy == 2:
        hk_array = hk_array_3
        print("Setting up hk array for Case Study 2")
        
    elif caseStudy == 3:
        hk_array = hk_array_4
        print("Setting up hk array for Case Study 3")
        
    else:
        print("This case study is not a viable option, choose a value from 1 to 4")
    
    uwp = flopy.modflow.mfupw.ModflowUpw(mf, hk=hk_array, vka=vka, sy=sy, ss=ss, ipakcb=53, iphdry = 53,
                                                 laytyp=laytyp) # MODFLOW- NWT
    print("Upstream weighting package set up")
        
    # --- Solver --- #
            
    nwt = flopy.modflow.mfnwt.ModflowNwt(mf, headtol=1e-05, maxiterout=200, 
                        thickfact=1e-07, linmeth=2, iprnwt=1, ibotav=1, options='SPECIFIED', 
                        Continue=True, dbdtheta=0.9, dbdkappa=1e-05, dbdgamma=0.0, momfact=0.1, 
                        backflag=1, maxbackiter=30, backtol=1.05, backreduce=0.9, maxitinner=50, 
                        ilumethod=2, levfill=5, stoptol=1e-10, msdr=15, iacl=2, norder=1, level=3, 
                        north=7, iredsys=1, rrctols=0.0, idroptol=1, epsrn=0.0001, 
                        hclosexmd=0.0001, mxiterxmd=200) # MODFLOW- NWT fluxtol=1e-3, 
                                                   
    print("Newton solver set up")
        
    # --- Recharge --- #
        
    if rechargeScenario == 0:
        recharge_array = recharge_array_1
        print("Setting up recharge array for Recharge Scenario 1")
    
    elif rechargeScenario == 1:
        recharge_array = recharge_array_2
        print("Setting up recharge array for Recharge Scenario 2")

    else:
        print("This Recharge Scenario is not a viable option, choose a value from 1 to 2")
    
    rch = flopy.modflow.ModflowRch(mf, rech=recharge_array)
        
    print("Recharge package set up")
        
    # --- General head boundaries --- #
        
    ghb = flopy.modflow.ModflowGhb(mf, stress_period_data=ghb_spd)
        
    print("General head boundary package set up")
        
    # --- SETTING UP THE OUTPUT CONTROL --- #
        
    spd = {}
    for strsp in range(nper):
        tmstp = nstp[strsp]
        for t in range(tmstp):
            spd[strsp, t] = ['save budget', 'print budget', 'save head'] 
                                       
    oc = flopy.modflow.ModflowOc(mf, stress_period_data=spd, compact=True)
        
    print("Output control package set up")
        
    # --- SETTING UP BASIC PACKAGE, IBOUND --- #
        
    bas = flopy.modflow.ModflowBas(mf, ibound=1., strt=float(sHead), 
                                       ifrefm=True, ixsec=False, hnoflo=-999.99)
        
    print("Basic package set up") 
        
    # --- LINKING FILE --- #
        
    # Set up the linking file for output from flow model to be used in transport model
    lmt = flopy.modflow.ModflowLmt(mf, output_file_name= (modelname + str('_mt3dLink.ftl')),
                                       output_file_header='extended',
                                       output_file_format='unformatted')   
                                        
    print("Link-Mass Transport package set up") 
        
    # --- NOW I NEED TO COMPILE AND WRITE ALL OF THE INPUT FILES --- #
          
    mf.write_input() # Write the model input files
           
    print("Input written")
        
    # Setting up subprocess AND RUNNING THE MODEL
    #---------------------------------------------------------------
    p = subprocess.Popen([MODFLOW_folder, modelname], shell = False)   
    p.wait()
    #---------------------------------------------------------------
    print("END: Flow model has been run")
    
    return modelname, modelname_mt3d, mf

# %% [markdown]
# ## Running the flow model
#
# Just a test, running one model at a time. I will run them all below.

# %%
t1 = time.time()  
modelname, modelname_mt3d, mf = flow_model(0, 0)
t2 = time.time()  
run_time = t2-t1      
print("Flow model run time: " + str(run_time) + "seconds")
# Out:
# Flow model name: TB_01_R0_CS0
# Transport model name: TB_01_mt3d_R0_CS0
# Discretisation module set up
# Setting up hk array for Case Study 0
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 1
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# Flow model run time: 7.480955123901367seconds

# %% [markdown]
# # Function to set up and run transport file

# %%
print("Modflow model details: %s" %mf)
print("Modflow model name is: %s" %modelname)
print("Mt3d model name is: %s"%modelname_mt3d)
print("MT3D executable is: %s" %MT3D_USGS_folder)
# Out:
# Modflow model details: MODFLOW 12 layer(s) 100 row(s) 200 column(s) 1 stress period(s)
# Modflow model name is: TB_01_R0_CS0
# Mt3d model name is: TB_01_mt3d_R0_CS0
# MT3D executable is: MT3D-USGS_64.exe

# %%
def transport_model(modelname, modelname_mt3d, mf):   

    mt = mt3d.Mt3dms(modflowmodel=mf, modelname=modelname_mt3d, model_ws=project_folder, 
                         version=mt3d_version, namefile_ext='mtnam', exe_name=MT3D_USGS_folder,  
                         ftlfilename=(modelname + str('_mt3dLink.ftl'))) 
               
    #------------------------------------------------------------------------------
    # BASIC TRANSPORT PACKAGE
        
    ncomp = 1         # Total number of chemical species in simulation.  
    mcomp = 1         # Total number of "mobile" species. 
    sconc= np.zeros((nlay, nrow, ncol), dtype=np.float32)  # initial conc. = 0 yrs   
    nprs = 0          # Flag indicating frequency of output. = 0: results not saved except 
                      # at end of simulation; > 0: saved at times specified by timprs; < 0: saved
                      # whenever the  number of transport steps is an even multiple of nprs.
        
    btn = mt3d.Mt3dBtn(mt, nlay=nlay, nrow=nrow, ncol=ncol, nper=nper, perlen=perlen, 
                           ncomp=ncomp, mcomp=mcomp, sconc=sconc, prsity=prsity,
                           delr=delr, delc=delc, icbund=1, ifmtcn=-1, savucn=True,
                           nprs=nprs, nprobs=1, cinact=0, ssflag='SState', laycon=1) 
        
    #------------------------------------------------------------------------------
    # ADVECTION PACKAGE
        
    adv = mt3d.Mt3dAdv(mt, mixelm=0)  
        
    # mixelm = 0 means that I am using the standard finite-difference method with upstream or 
    # central-in-stream weighting, depending on the value of NADVFD. 
    # Other options, MOC (1); MMOC (2); HMOC (3); TVD (-1). 
        
    #------------------------------------------------------------------------------
    # GENERALISED CONJUGATE GRADIENT SOLVER for MT3D-USGS
        
    gcg = mt3d.Mt3dGcg(mt, mxiter=30, iter1=50, isolve=2, accl=1, cclose=1e-06)
        
    #------------------------------------------------------------------------------
    # REACTION PACKAGE
        
    rc1 = np.zeros((nlay, nrow, ncol), dtype=np.float32)
    rc1[:, :, :] = -1/365.25
        
    isothm = 0      # 0 = no sorption.
    ireact = 100    # 100 = zeroth-order reaction option.
    rc1 = rc1       # First order reaction rate for diffolved phase of first species.
        
    rct= mt3d.Mt3dRct(mt, isothm=isothm, ireact=ireact, igetsc=0, rc1=rc1) 
        
    #------------------------------------------------------------------------------
    # SOURCE-SINK MIXING PACKAGE
        
    crch = np.zeros((nrow, ncol), dtype=np.float32) # The age of recharging water is 0
        
    itype = mt3d.Mt3dSsm.itype_dict()
       
    ssm = mt3d.Mt3dSsm(mt, crch=crch) #, stress_period_data=ssm_data) 
        
    #------------------------------------------------------------------------------
    # DISPERSION PACKAGE 
    al = 1.5 # The longitudinal dispersivity, default = 0.01

#   trpt = 0.1  #ratio of horizontal transverse: longitudinal dispersivity, default = 0.1
#   trpv = 0.01 #ratio of vertical transverse dispersivity: longitudinal dispersivity, default = 0.01
    dmcoef = 1E-4*tortuosity_factor # Effective molecular diffusion coefficient (for water in my model), default = 1E-9 m2/s
        
    # Instantiate up the Dispersion package for MT3D-USGS
    dsp = mt3d.Mt3dDsp(mt, al=al, dmcoef=dmcoef) 
        
    #----- WRITING transport MODEL ------------------------------------------------
         
    mt.write_input()
       
    # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
    # -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
    # "Manual" changes to the input files
    conc_filename_dissolved = str(modelname_mt3d) + ".ucn"
    conc_filename_sorbed = str(modelname_mt3d) + "_S.ucn"
    mass_filename = str(modelname_mt3d) + ".mas"
    cnf_filename = str(modelname_mt3d) + ".cnf"
        
    ##Add a line to the MT3D .mtnam file re-naming output UCN file + MAS,CNF
    mt_name_file = modelname_mt3d + str('.mtnam')
        
    namfile = open(mt_name_file, 'a')
    namfile.write('data(binary) 201 %s \n' %(conc_filename_dissolved))
    namfile.close()
        
    namfile = open(mt_name_file, 'a')
    namfile.write('data(binary) 301 %s \n' %(conc_filename_sorbed))
    namfile.close()
              
    namfile = open(mt_name_file, 'a')
    namfile.write('data 601 %s \n' %(mass_filename))
    namfile.close()
        
    namfile = open(mt_name_file, 'a')
    namfile.write('data 17 %s \n' %(cnf_filename))
    namfile.close()
                
    ###For USGS need to add DRYCELL keyword to the .btn file on line 3
    mt_btn_file = modelname_mt3d + str('.btn')
        

    btnfile = open(mt_btn_file, "r")
    contents = btnfile.readlines()
    btnfile.close()
    contents.insert(2, "DRYCELL \n")
    btnfile = open(mt_btn_file, "w")
    contents = "".join(contents)
    btnfile.write(contents)
    btnfile.close()
        
    # ADD SSTATE FLAG manually in correct spot

    fpath = os.path.join(project_folder, mt_btn_file)
    with open(mt_btn_file, 'r+') as f:
        lines = f.readlines()
        f.seek(0)
        f.truncate()

        a = '%.1E' % Decimal(length_simulation)
        if length_simulation == 1:
            b = "1         1         1 S"
            c = "1         1         1         SState"
        else:
            b = str(a) + "         1         1 S"
            c = str(a) + "         1         1         SState"

        ##

        for line in lines:
            if b in line:
                            line = line.replace(b, c)
            f.write(line)
            
    # Running the transport model
    #--------------------------------
    success, buff = mt.run_model()
    print("Transport model has been run")
    #-------------------------------- 
        
    return mt

# %% [markdown]
# ## Running the transport model
#
# Again just a test, running one model at a time. I will run them all below.

# %%
print(mf)
print(modelname)
print(modelname_mt3d)
# Out:
# MODFLOW 12 layer(s) 100 row(s) 200 column(s) 1 stress period(s)
# TB_01_R0_CS0
# TB_01_mt3d_R0_CS0

# %%
t1 = time.time()
mt = transport_model(modelname, modelname_mt3d, mf)
t2 = time.time()  
run_time = t2-t1      
print("Transport model run time: " + str(run_time) + "seconds")
# Out:
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R0_CS0.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3286E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5029E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6234E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =   6351.      [K,I,J]   12   99  169
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =   1504.      [K,I,J]   12   98  200
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =   2466.      [K,I,J]   12   97  200
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =   212.3      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =   162.8      [K,I,J]   12   95  200
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =   29.76      [K,I,J]   12   71  200
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =   6.359      [K,I,J]   12   57  200
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =   2.742      [K,I,J]   12   98  185
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =   2.713      [K,I,J]   12   79  200
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4297      [K,I,J]   12    2  200
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8203E-01  [K,I,J]   12   98  193
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.3906E-01  [K,I,J]   12   98  199
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.3516E-01  [K,I,J]   12   98  198
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.9766E-02  [K,I,J]   12    1  199
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1953E-02  [K,I,J]   12    1  199
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.1224E-01  [K,I,J]   11  100    1
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.1681E-02  [K,I,J]   11  100    1
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.6703E-03  [K,I,J]   12   99   42
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.7628E-03  [K,I,J]   12   99   94
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.1553E-01  [K,I,J]   12   99   73
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.1595E-01  [K,I,J]   12   99   73
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.5227E-04  [K,I,J]   12   98  200
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.3165E-04  [K,I,J]   12    1  200
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.4226E-04  [K,I,J]   12    1  200
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.1240E-04  [K,I,J]   12    1  200
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.2617E-04  [K,I,J]   12    1  200
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.8583E-05  [K,I,J]   12   98  158
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.7331E-05  [K,I,J]   12   98  157
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.2027E-05  [K,I,J]   12   98  199
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.1252E-05  [K,I,J]   12   98  197
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.3576E-06  [K,I,J]   12    1  198
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.1539E-03  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.1526E-04  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.2563E-05  [K,I,J]   11  100    1
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.3159E-05  [K,I,J]   12   12   74
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.2027E-05  [K,I,J]   12    3   65
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.2384E-06  [K,I,J]   12    3  148
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.2742E-05  [K,I,J]   12    1    1
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.7153E-06  [K,I,J]   12    6  129
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.1431E-05  [K,I,J]   12   35  194
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.1788E-06  [K,I,J]   12    3  142
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.1132E-05  [K,I,J]   12   15  184
#  Outer Iter.  6  Inner Iter.  2:  Max. DC =  0.4172E-06  [K,I,J]   12   15  199
#  Outer Iter.  7  Inner Iter.  1:  Max. DC =  0.8941E-06  [K,I,J]   12    1  199
#
#  Program completed.   Total CPU time:  000 minutes  2.672 seconds
# Transport model has been run
# Transport model run time: 3.7781479358673096seconds

# %% [markdown]
# # Running all case studies

# %%
t1 = time.time()
for rechargeScenario in range(number_of_recharge_scenarios): # number_of_recharge_scenarios
    print("Recharge scenario: " + str(rechargeScenario))
    
    for caseStudy in range(number_of_casestudies): # number_of_casestudies
        print("Case study: " + str(caseStudy))

        modelname, modelname_mt3d, mf = flow_model(rechargeScenario, caseStudy)
        mt = transport_model(modelname, modelname_mt3d, mf)

print("Finished running all scenarios")
t2 = time.time()  
run_time = t2-t1      
print("Total run time: " + str(run_time) + "seconds")
# Out:
# Recharge scenario: 0
# Case study: 0
# Flow model name: TB_01_R0_CS0
# Transport model name: TB_01_mt3d_R0_CS0
# Discretisation module set up
# Setting up hk array for Case Study 0
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 1
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R0_CS0.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3286E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5029E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6234E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =   6351.      [K,I,J]   12   99  169
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =   1504.      [K,I,J]   12   98  200
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =   2466.      [K,I,J]   12   97  200
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =   212.3      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =   162.8      [K,I,J]   12   95  200
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =   29.76      [K,I,J]   12   71  200
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =   6.359      [K,I,J]   12   57  200
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =   2.742      [K,I,J]   12   98  185
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =   2.713      [K,I,J]   12   79  200
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4297      [K,I,J]   12    2  200
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8203E-01  [K,I,J]   12   98  193
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.3906E-01  [K,I,J]   12   98  199
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.3516E-01  [K,I,J]   12   98  198
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.9766E-02  [K,I,J]   12    1  199
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1953E-02  [K,I,J]   12    1  199
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.1224E-01  [K,I,J]   11  100    1
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.1681E-02  [K,I,J]   11  100    1
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.6703E-03  [K,I,J]   12   99   42
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.7628E-03  [K,I,J]   12   99   94
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.1553E-01  [K,I,J]   12   99   73
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.1595E-01  [K,I,J]   12   99   73
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.5227E-04  [K,I,J]   12   98  200
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.3165E-04  [K,I,J]   12    1  200
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.4226E-04  [K,I,J]   12    1  200
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.1240E-04  [K,I,J]   12    1  200
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.2617E-04  [K,I,J]   12    1  200
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.8583E-05  [K,I,J]   12   98  158
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.7331E-05  [K,I,J]   12   98  157
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.2027E-05  [K,I,J]   12   98  199
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.1252E-05  [K,I,J]   12   98  197
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.3576E-06  [K,I,J]   12    1  198
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.1539E-03  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.1526E-04  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.2563E-05  [K,I,J]   11  100    1
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.3159E-05  [K,I,J]   12   12   74
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.2027E-05  [K,I,J]   12    3   65
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.2384E-06  [K,I,J]   12    3  148
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.2742E-05  [K,I,J]   12    1    1
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.7153E-06  [K,I,J]   12    6  129
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.1431E-05  [K,I,J]   12   35  194
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.1788E-06  [K,I,J]   12    3  142
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.1132E-05  [K,I,J]   12   15  184
#  Outer Iter.  6  Inner Iter.  2:  Max. DC =  0.4172E-06  [K,I,J]   12   15  199
#  Outer Iter.  7  Inner Iter.  1:  Max. DC =  0.8941E-06  [K,I,J]   12    1  199
#
#  Program completed.   Total CPU time:  000 minutes  2.859 seconds
# Transport model has been run
# Case study: 1
# Flow model name: TB_01_R0_CS1
# Transport model name: TB_01_mt3d_R0_CS1
# Discretisation module set up
# Setting up hk array for Case Study 1
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 1
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R0_CS1.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3209E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1237E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6127E+05  [K,I,J]   12   48  101
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1288E+06  [K,I,J]   12   86  105
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2714E+06  [K,I,J]   12   77  107
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7688E+08  [K,I,J]   12   78  109
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7649E+08  [K,I,J]   12   78  109
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2420E+05  [K,I,J]   12   77  108
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2890E+06  [K,I,J]   12   73  107
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7063E+06  [K,I,J]   10   46  101
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1330E+06  [K,I,J]   10   46  101
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6246E+06  [K,I,J]   10   46  101
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1223E+07  [K,I,J]    9   46  101
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1834E+07  [K,I,J]    9   46  101
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.2300E+06  [K,I,J]   12   46  101
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.8606E+06  [K,I,J]   10   45  101
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1427E+07  [K,I,J]   10   45  101
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1478E+07  [K,I,J]   10   45  101
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.9558E+06  [K,I,J]   10   45  101
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.7679E+07  [K,I,J]   10   45  101
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.1460E+08  [K,I,J]   10   45  101
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.1124E+07  [K,I,J]   10   45  101
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.4456E+07  [K,I,J]   12   69  109
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.7399E+07  [K,I,J]   12   68  110
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.9420E+07  [K,I,J]   12   68  110
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.1427E+07  [K,I,J]   12   68  110
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.3529E+06  [K,I,J]   10   46  101
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.1969E+08  [K,I,J]   12   69  109
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =  0.1536E+08  [K,I,J]   12   69  109
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =  0.1976E+07  [K,I,J]   12   69  109
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =  0.3128E+07  [K,I,J]   12   69  109
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =  0.5473E+07  [K,I,J]   12   69  109
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =  0.9927E+06  [K,I,J]   12   67  111
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =  0.6240E+07  [K,I,J]   12   67  110
#  Outer Iter.  1  Inner Iter. 35:  Max. DC =  0.1280E+07  [K,I,J]   12   67  110
#  Outer Iter.  1  Inner Iter. 36:  Max. DC =  0.7992E+07  [K,I,J]   12   67  110
#  Outer Iter.  1  Inner Iter. 37:  Max. DC =  0.7359E+06  [K,I,J]   12   67  110
#  Outer Iter.  1  Inner Iter. 38:  Max. DC =  0.3534E+07  [K,I,J]   12   69  109
#  Outer Iter.  1  Inner Iter. 39:  Max. DC =  0.6274E+07  [K,I,J]   12   69  109
#  Outer Iter.  1  Inner Iter. 40:  Max. DC =  0.3101E+07  [K,I,J]   12   69  109
#  Outer Iter.  1  Inner Iter. 41:  Max. DC =  0.1853E+07  [K,I,J]   12   68  109
#  Outer Iter.  1  Inner Iter. 42:  Max. DC =  0.7088E+07  [K,I,J]   12   67  110
#  Outer Iter.  1  Inner Iter. 43:  Max. DC =  0.4449E+07  [K,I,J]   12   67  110
#  Outer Iter.  1  Inner Iter. 44:  Max. DC =  0.3001E+07  [K,I,J]   12   68  112
#  Outer Iter.  1  Inner Iter. 45:  Max. DC =  0.9387E+06  [K,I,J]   12   68  110
#  Outer Iter.  1  Inner Iter. 46:  Max. DC =  0.6476E+07  [K,I,J]   12   66  111
#  Outer Iter.  1  Inner Iter. 47:  Max. DC =  0.1999E+07  [K,I,J]   12   67  112
#  Outer Iter.  1  Inner Iter. 48:  Max. DC =  0.2898E+08  [K,I,J]   12   68  110
#  Outer Iter.  1  Inner Iter. 49:  Max. DC =  0.3021E+08  [K,I,J]   12   68  110
#  Outer Iter.  1  Inner Iter. 50:  Max. DC =  0.5604E+06  [K,I,J]   12   67  110
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =   1.037      [K,I,J]   12   67  110
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.1144      [K,I,J]   12   68  111
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.2252E-01  [K,I,J]   12   67  109
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.5573      [K,I,J]   12   67  110
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.8786      [K,I,J]   12   72  164
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.5853      [K,I,J]   12   72  165
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.2574      [K,I,J]   12   67  110
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.5487E-03  [K,I,J]   12   77  145
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.1299E-02  [K,I,J]   12   77  147
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.1058E-01  [K,I,J]   12   66  111
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.1126E-01  [K,I,J]   12   66  111
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.1076E-02  [K,I,J]   12   10   98
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.1161E-02  [K,I,J]    9   75  150
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.2411E-02  [K,I,J]    9   75  150
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.3865E-03  [K,I,J]   10   75  153
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.2718E-02  [K,I,J]    9   75  150
#  Outer Iter.  2  Inner Iter. 17:  Max. DC =  0.1314E-02  [K,I,J]   10   75  152
#  Outer Iter.  2  Inner Iter. 18:  Max. DC =  0.3561E-02  [K,I,J]   12   74  150
#  Outer Iter.  2  Inner Iter. 19:  Max. DC =  0.3597E-02  [K,I,J]   12   74  150
#  Outer Iter.  2  Inner Iter. 20:  Max. DC =  0.3312E-03  [K,I,J]    8   74  148
#  Outer Iter.  2  Inner Iter. 21:  Max. DC =  0.2744E-03  [K,I,J]    8   74  147
#  Outer Iter.  2  Inner Iter. 22:  Max. DC =  0.1816E-03  [K,I,J]    7   74  147
#  Outer Iter.  2  Inner Iter. 23:  Max. DC =  0.1827E-04  [K,I,J]   12   31  200
#  Outer Iter.  2  Inner Iter. 24:  Max. DC =  0.7905E-04  [K,I,J]   12   31  200
#  Outer Iter.  2  Inner Iter. 25:  Max. DC =  0.9425E-04  [K,I,J]   12   30  200
#  Outer Iter.  2  Inner Iter. 26:  Max. DC =  0.5942E-04  [K,I,J]   12   30  200
#  Outer Iter.  2  Inner Iter. 27:  Max. DC =  0.1569E-04  [K,I,J]   12   31  200
#  Outer Iter.  2  Inner Iter. 28:  Max. DC =  0.1733E-05  [K,I,J]   12   30  200
#  Outer Iter.  2  Inner Iter. 29:  Max. DC =  0.4112E-05  [K,I,J]   12   30  200
#  Outer Iter.  2  Inner Iter. 30:  Max. DC =  0.8894E-05  [K,I,J]   12   30  200
#  Outer Iter.  2  Inner Iter. 31:  Max. DC =  0.2865E-05  [K,I,J]   12   31  200
#  Outer Iter.  2  Inner Iter. 32:  Max. DC =  0.4543E-06  [K,I,J]    8   73  149
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.6251      [K,I,J]   10   43  101
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.1434      [K,I,J]   10   42  101
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.7883E-01  [K,I,J]   11   42  101
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.4288E-02  [K,I,J]   10   42  101
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.1745E-01  [K,I,J]   10   42  101
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.2890E-02  [K,I,J]   10   42  101
#  Outer Iter.  3  Inner Iter.  7:  Max. DC =  0.6926E-03  [K,I,J]   12   10   98
#  Outer Iter.  3  Inner Iter.  8:  Max. DC =  0.2684E-02  [K,I,J]   10   42  101
#  Outer Iter.  3  Inner Iter.  9:  Max. DC =  0.4117E-02  [K,I,J]   10   42  101
#  Outer Iter.  3  Inner Iter. 10:  Max. DC =  0.1477E-02  [K,I,J]   11   42  101
#  Outer Iter.  3  Inner Iter. 11:  Max. DC =  0.2938E-03  [K,I,J]   10   42  101
#  Outer Iter.  3  Inner Iter. 12:  Max. DC =  0.5541E-03  [K,I,J]   10   42  101
#  Outer Iter.  3  Inner Iter. 13:  Max. DC =  0.1079E-02  [K,I,J]   11   42  101
#  Outer Iter.  3  Inner Iter. 14:  Max. DC =  0.1456E-02  [K,I,J]   11   42  101
#  Outer Iter.  3  Inner Iter. 15:  Max. DC =  0.1853E-03  [K,I,J]   12    8  101
#  Outer Iter.  3  Inner Iter. 16:  Max. DC =  0.1022E-03  [K,I,J]   12   71  148
#  Outer Iter.  3  Inner Iter. 17:  Max. DC =  0.1012E-03  [K,I,J]    9   71  145
#  Outer Iter.  3  Inner Iter. 18:  Max. DC =  0.2585E-05  [K,I,J]    7   71  143
#  Outer Iter.  3  Inner Iter. 19:  Max. DC =  0.1647E-03  [K,I,J]   11   69  155
#  Outer Iter.  3  Inner Iter. 20:  Max. DC =  0.1826E-03  [K,I,J]   10   69  154
#  Outer Iter.  3  Inner Iter. 21:  Max. DC =  0.6399E-04  [K,I,J]    9   69  150
#  Outer Iter.  3  Inner Iter. 22:  Max. DC =  0.1082E-04  [K,I,J]    9   68  157
#  Outer Iter.  3  Inner Iter. 23:  Max. DC =  0.2474E-05  [K,I,J]    8   71  148
#  Outer Iter.  3  Inner Iter. 24:  Max. DC =  0.1207E-05  [K,I,J]    8   66  148
#  Outer Iter.  3  Inner Iter. 25:  Max. DC =  0.5513E-06  [K,I,J]    7   71  146
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.1736E-01  [K,I,J]   12   76  113
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.5265E-02  [K,I,J]   10   44  101
#  Outer Iter.  4  Inner Iter.  3:  Max. DC =  0.3052E-02  [K,I,J]   10   44  101
#  Outer Iter.  4  Inner Iter.  4:  Max. DC =  0.1896E-03  [K,I,J]   10   44  101
#  Outer Iter.  4  Inner Iter.  5:  Max. DC =  0.5618E-03  [K,I,J]   12   43  101
#  Outer Iter.  4  Inner Iter.  6:  Max. DC =  0.2226E-03  [K,I,J]   10   44  101
#  Outer Iter.  4  Inner Iter.  7:  Max. DC =  0.2515E-04  [K,I,J]   11   42  101
#  Outer Iter.  4  Inner Iter.  8:  Max. DC =  0.2789E-04  [K,I,J]   10   44  101
#  Outer Iter.  4  Inner Iter.  9:  Max. DC =  0.7403E-04  [K,I,J]   10   44  101
#  Outer Iter.  4  Inner Iter. 10:  Max. DC =  0.4512E-04  [K,I,J]   10   41  101
#  Outer Iter.  4  Inner Iter. 11:  Max. DC =  0.2720E-03  [K,I,J]   10   41  101
#  Outer Iter.  4  Inner Iter. 12:  Max. DC =  0.2842E-03  [K,I,J]   10   41  101
#  Outer Iter.  4  Inner Iter. 13:  Max. DC =  0.2569E-04  [K,I,J]   10   41  101
#  Outer Iter.  4  Inner Iter. 14:  Max. DC =  0.5603E-05  [K,I,J]   10   41  101
#  Outer Iter.  4  Inner Iter. 15:  Max. DC =  0.5484E-05  [K,I,J]   10   41  101
#  Outer Iter.  4  Inner Iter. 16:  Max. DC =  0.1091E-04  [K,I,J]   11   72  144
#  Outer Iter.  4  Inner Iter. 17:  Max. DC =  0.7778E-05  [K,I,J]    8   71  138
#  Outer Iter.  4  Inner Iter. 18:  Max. DC =  0.1329E-04  [K,I,J]    9   72  144
#  Outer Iter.  4  Inner Iter. 19:  Max. DC =  0.7331E-05  [K,I,J]    8   70  143
#  Outer Iter.  4  Inner Iter. 20:  Max. DC =  0.2712E-05  [K,I,J]    8   69  145
#  Outer Iter.  4  Inner Iter. 21:  Max. DC =  0.1878E-05  [K,I,J]    7   69  142
#  Outer Iter.  4  Inner Iter. 22:  Max. DC =  0.8941E-06  [K,I,J]    8   68  147
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.1913E-03  [K,I,J]   12   76  114
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.5633E-04  [K,I,J]   11   42  101
#  Outer Iter.  5  Inner Iter.  3:  Max. DC =  0.3475E-04  [K,I,J]   11   42  101
#  Outer Iter.  5  Inner Iter.  4:  Max. DC =  0.3576E-05  [K,I,J]   11   42  101
#  Outer Iter.  5  Inner Iter.  5:  Max. DC =  0.1299E-04  [K,I,J]   11   42  101
#  Outer Iter.  5  Inner Iter.  6:  Max. DC =  0.2086E-05  [K,I,J]   11   42  101
#  Outer Iter.  5  Inner Iter.  7:  Max. DC =  0.5960E-07  [K,I,J]   10   40  101
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.2861E-05  [K,I,J]   12   77  113
#  Outer Iter.  6  Inner Iter.  2:  Max. DC =  0.8470E-04  [K,I,J]   12   78  116
#  Outer Iter.  6  Inner Iter.  3:  Max. DC =  0.8559E-04  [K,I,J]   12   78  116
#  Outer Iter.  6  Inner Iter.  4:  Max. DC =  0.2980E-06  [K,I,J]   12   75  119
#  Outer Iter.  7  Inner Iter.  1:  Max. DC =  0.7749E-06  [K,I,J]   12    4  171
#
#  Program completed.   Total CPU time:  000 minutes  4.484 seconds
# Transport model has been run
# Case study: 2
# Flow model name: TB_01_R0_CS2
# Transport model name: TB_01_mt3d_R0_CS2
# Discretisation module set up
# Setting up hk array for Case Study 2
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 1
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R0_CS2.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3099E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   1802.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2707E+05  [K,I,J]   10  100  101
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1569E+05  [K,I,J]   12  100  101
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =   4305.      [K,I,J]   12   99   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =   2270.      [K,I,J]   10   99  101
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =   3096.      [K,I,J]   12   98  200
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =   604.5      [K,I,J]    9   99  101
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =   61.84      [K,I,J]   12   53  200
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =   235.5      [K,I,J]   12   54  200
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =   71.79      [K,I,J]   12   54  200
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =   12.83      [K,I,J]    8   51  101
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =   2.274      [K,I,J]   12   99  182
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =   7.002      [K,I,J]   12   99  157
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =   3.406      [K,I,J]   12   52  200
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2949      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.2275      [K,I,J]   11   50  200
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.2363      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.3223E-01  [K,I,J]    6  100  101
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2246E-01  [K,I,J]   12   98  186
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.1465E-01  [K,I,J]   11   27  200
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.6836E-02  [K,I,J]    6  100  101
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.2930E-02  [K,I,J]    6  100  101
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.9766E-03  [K,I,J]   12   98  183
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.9766E-03  [K,I,J]    6  100  101
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.1325E-01  [K,I,J]    8  100  101
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.3341E-02  [K,I,J]   11  100    1
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.8112E-02  [K,I,J]   12   99  141
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.8868E-02  [K,I,J]   12   99  151
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.2388E-03  [K,I,J]   11  100  101
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.6959E-03  [K,I,J]   11  100  101
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.1224E-03  [K,I,J]   11  100  101
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.7170E-04  [K,I,J]   12   40  144
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.2372E-04  [K,I,J]   12   99  197
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.1532E-04  [K,I,J]   12   29  200
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.1323E-04  [K,I,J]   12   34  200
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.4351E-05  [K,I,J]   12   40  200
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.4768E-05  [K,I,J]   12   28  200
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.3338E-05  [K,I,J]   12   39  200
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.1788E-05  [K,I,J]   12   41  200
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.2384E-06  [K,I,J]   12   99  196
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.3247E-03  [K,I,J]    7   19  101
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.6956E-04  [K,I,J]   10   15  101
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.1025E-03  [K,I,J]   12   16  140
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.1445E-03  [K,I,J]   12   24  145
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.1258E-04  [K,I,J]   12   42  140
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.5662E-05  [K,I,J]   12    1  127
#  Outer Iter.  3  Inner Iter.  7:  Max. DC =  0.1073E-05  [K,I,J]   12   14  200
#  Outer Iter.  3  Inner Iter.  8:  Max. DC =  0.6557E-06  [K,I,J]   12   23  200
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.7749E-05  [K,I,J]    7    2  101
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.2086E-05  [K,I,J]    9   40  101
#  Outer Iter.  4  Inner Iter.  3:  Max. DC =  0.3576E-06  [K,I,J]   12    1  137
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.1252E-05  [K,I,J]   12   76  179
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.5364E-06  [K,I,J]   11   46  101
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.7749E-06  [K,I,J]   12   30  100
#
#  Program completed.   Total CPU time:  000 minutes  2.812 seconds
# Transport model has been run
# Recharge scenario: 1
# Case study: 0
# Flow model name: TB_01_R1_CS0
# Transport model name: TB_01_mt3d_R1_CS0
# Discretisation module set up
# Setting up hk array for Case Study 0
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 2
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R1_CS0.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1297E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   7378.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =   5365.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =   6222.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4558E+06  [K,I,J]   12   98  200
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4406E+06  [K,I,J]   12   98  200
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =   8352.      [K,I,J]   12   98  200
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =   3112.      [K,I,J]   12   98  200
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =   1765.      [K,I,J]   12   43  200
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =   1203.      [K,I,J]   12   43  200
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =   884.3      [K,I,J]   12   43  200
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =   637.8      [K,I,J]   12   43  200
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =   475.0      [K,I,J]   12   99   29
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =   344.9      [K,I,J]   12   99   31
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =   73.43      [K,I,J]   12   99   31
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =   254.3      [K,I,J]   12  100    5
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =   576.5      [K,I,J]   12  100    5
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =   825.0      [K,I,J]   12  100    5
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =   1010.      [K,I,J]   12  100    5
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =   1177.      [K,I,J]   12  100    5
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =   1364.      [K,I,J]   12  100    5
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =   1565.      [K,I,J]   12  100    4
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =   1705.      [K,I,J]   12  100    4
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =   1589.      [K,I,J]   12  100    4
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =   1053.      [K,I,J]   12  100    4
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =   266.8      [K,I,J]   12  100    4
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =   275.8      [K,I,J]   12  100    3
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =   517.1      [K,I,J]   12   99   82
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =   880.3      [K,I,J]   12   99  123
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =   1684.      [K,I,J]   12   99  116
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =   4174.      [K,I,J]   12   48  200
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =  0.1243E+05  [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =  0.1633E+06  [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =  0.2303E+06  [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 35:  Max. DC =  0.2174E+05  [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 36:  Max. DC =   6682.      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 37:  Max. DC =   3618.      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 38:  Max. DC =   2754.      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 39:  Max. DC =   3556.      [K,I,J]   12   99  125
#  Outer Iter.  1  Inner Iter. 40:  Max. DC =   6641.      [K,I,J]   12   99  127
#  Outer Iter.  1  Inner Iter. 41:  Max. DC =  0.1891E+05  [K,I,J]   12   99  128
#  Outer Iter.  1  Inner Iter. 42:  Max. DC =  0.2526E+06  [K,I,J]   12   99  128
#  Outer Iter.  1  Inner Iter. 43:  Max. DC =  0.3667E+06  [K,I,J]   12   99  127
#  Outer Iter.  1  Inner Iter. 44:  Max. DC =  0.2910E+05  [K,I,J]   12   99  128
#  Outer Iter.  1  Inner Iter. 45:  Max. DC =   3440.      [K,I,J]   12   99  137
#  Outer Iter.  1  Inner Iter. 46:  Max. DC =   83.85      [K,I,J]   12   99  117
#  Outer Iter.  1  Inner Iter. 47:  Max. DC =   7543.      [K,I,J]   12   99  121
#  Outer Iter.  1  Inner Iter. 48:  Max. DC =  0.1352E+05  [K,I,J]   12   99  122
#  Outer Iter.  1  Inner Iter. 49:  Max. DC =  0.1138E+05  [K,I,J]   12   99  123
#  Outer Iter.  1  Inner Iter. 50:  Max. DC =   7100.      [K,I,J]   12   99  123
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.9078      [K,I,J]   12   99  173
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.6338      [K,I,J]   12   99  155
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.3315      [K,I,J]   12   99  183
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.1851      [K,I,J]   12   98  200
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.1951E-01  [K,I,J]   12   51  200
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.3557E-01  [K,I,J]   12   99  170
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.1455E-01  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.2667E-02  [K,I,J]   12  100    8
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.3550E-02  [K,I,J]   12   46  200
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.3479E-02  [K,I,J]   12   45  200
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.2726E-02  [K,I,J]   12   48  200
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.1010E-03  [K,I,J]   12   42  200
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.1913E-04  [K,I,J]   12   38  200
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.1413E-04  [K,I,J]   12   38  200
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.2116E-04  [K,I,J]   12   39  200
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.8345E-06  [K,I,J]   12   15  200
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.8419E-02  [K,I,J]   11   48    1
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.2895E-03  [K,I,J]   11   48    1
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.1091E-02  [K,I,J]   11   48    1
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.1452E-02  [K,I,J]   12   99  126
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.9156E-03  [K,I,J]   12   99  103
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.1220E-03  [K,I,J]   12   45   21
#  Outer Iter.  3  Inner Iter.  7:  Max. DC =  0.2555E-03  [K,I,J]   12   42  200
#  Outer Iter.  3  Inner Iter.  8:  Max. DC =  0.3618E-04  [K,I,J]   12   99  180
#  Outer Iter.  3  Inner Iter.  9:  Max. DC =  0.6068E-04  [K,I,J]   12   40  200
#  Outer Iter.  3  Inner Iter. 10:  Max. DC =  0.1991E-04  [K,I,J]   12   34  200
#  Outer Iter.  3  Inner Iter. 11:  Max. DC =  0.7212E-05  [K,I,J]   12   30  200
#  Outer Iter.  3  Inner Iter. 12:  Max. DC =  0.2444E-05  [K,I,J]   12   31  200
#  Outer Iter.  3  Inner Iter. 13:  Max. DC =  0.5960E-07  [K,I,J]   11    1  196
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.1001E-03  [K,I,J]   12   45    1
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.2658E-04  [K,I,J]   12  100    1
#  Outer Iter.  4  Inner Iter.  3:  Max. DC =  0.1687E-04  [K,I,J]   12  100    1
#  Outer Iter.  4  Inner Iter.  4:  Max. DC =  0.6139E-05  [K,I,J]   12   17  112
#  Outer Iter.  4  Inner Iter.  5:  Max. DC =  0.3219E-05  [K,I,J]   12   12   88
#  Outer Iter.  4  Inner Iter.  6:  Max. DC =  0.8345E-06  [K,I,J]   12    4  200
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.2325E-05  [K,I,J]   12   50  200
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.8941E-06  [K,I,J]   12   97  200
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.1311E-05  [K,I,J]   11   80  198
#  Outer Iter.  6  Inner Iter.  2:  Max. DC =  0.7153E-06  [K,I,J]   12   65  198
#  Outer Iter.  7  Inner Iter.  1:  Max. DC =  0.1609E-05  [K,I,J]   12   46  199
#  Outer Iter.  7  Inner Iter.  2:  Max. DC =  0.1550E-05  [K,I,J]   12   38  186
#  Outer Iter.  7  Inner Iter.  3:  Max. DC =  0.8345E-06  [K,I,J]   12   38  186
#  Outer Iter.  8  Inner Iter.  1:  Max. DC =  0.1073E-05  [K,I,J]   12   83  193
#  Outer Iter.  8  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   10   36  197
#  Outer Iter.  9  Inner Iter.  1:  Max. DC =  0.1013E-05  [K,I,J]   12   49  160
#  Outer Iter.  9  Inner Iter.  2:  Max. DC =  0.3916E-04  [K,I,J]   12    6  167
#  Outer Iter.  9  Inner Iter.  3:  Max. DC =  0.3880E-04  [K,I,J]   12    6  167
#  Outer Iter.  9  Inner Iter.  4:  Max. DC =  0.1788E-06  [K,I,J]   11    5  200
#  Outer Iter. 10  Inner Iter.  1:  Max. DC =  0.1013E-05  [K,I,J]   12    9  189
#  Outer Iter. 10  Inner Iter.  2:  Max. DC =  0.2980E-06  [K,I,J]   12   31  160
#  Outer Iter. 11  Inner Iter.  1:  Max. DC =  0.1013E-05  [K,I,J]   12   56  176
#  Outer Iter. 11  Inner Iter.  2:  Max. DC =  0.7153E-06  [K,I,J]   12   20  188
#  Outer Iter. 12  Inner Iter.  1:  Max. DC =  0.1490E-05  [K,I,J]   12   73  194
#  Outer Iter. 12  Inner Iter.  2:  Max. DC =  0.1192E-05  [K,I,J]   12   38  200
#  Outer Iter. 12  Inner Iter.  3:  Max. DC =  0.5364E-06  [K,I,J]   12   38  193
#  Outer Iter. 13  Inner Iter.  1:  Max. DC =  0.1013E-05  [K,I,J]   12    3  199
#  Outer Iter. 13  Inner Iter.  2:  Max. DC =  0.2384E-06  [K,I,J]   12    4  195
#  Outer Iter. 14  Inner Iter.  1:  Max. DC =  0.1192E-05  [K,I,J]   12   17  187
#  Outer Iter. 14  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   12   27  188
#  Outer Iter. 15  Inner Iter.  1:  Max. DC =  0.1073E-05  [K,I,J]   12   34  183
#  Outer Iter. 15  Inner Iter.  2:  Max. DC =  0.1788E-06  [K,I,J]   12   21  190
#  Outer Iter. 16  Inner Iter.  1:  Max. DC =  0.1192E-05  [K,I,J]   12   13  200
#  Outer Iter. 16  Inner Iter.  2:  Max. DC =  0.2027E-05  [K,I,J]   12   56  188
#  Outer Iter. 16  Inner Iter.  3:  Max. DC =  0.1371E-05  [K,I,J]   12   56  184
#  Outer Iter. 16  Inner Iter.  4:  Max. DC =  0.5960E-07  [K,I,J]    6   82  200
#  Outer Iter. 17  Inner Iter.  1:  Max. DC =  0.1252E-05  [K,I,J]   12   39  193
#  Outer Iter. 17  Inner Iter.  2:  Max. DC =  0.2980E-06  [K,I,J]   12   23  196
#  Outer Iter. 18  Inner Iter.  1:  Max. DC =  0.1013E-05  [K,I,J]   12   16  165
#  Outer Iter. 18  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   12   16  177
#  Outer Iter. 19  Inner Iter.  1:  Max. DC =  0.1013E-05  [K,I,J]   12   39  168
#  Outer Iter. 19  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]    9   21  169
#  Outer Iter. 20  Inner Iter.  1:  Max. DC =  0.1013E-05  [K,I,J]   12   23  187
#  Outer Iter. 20  Inner Iter.  2:  Max. DC =  0.1311E-05  [K,I,J]   12   87  173
#  Outer Iter. 20  Inner Iter.  3:  Max. DC =  0.1729E-05  [K,I,J]   12   87  173
#  Outer Iter. 20  Inner Iter.  4:  Max. DC =  0.5960E-07  [K,I,J]    4   44  193
#  Outer Iter. 21  Inner Iter.  1:  Max. DC =  0.1073E-05  [K,I,J]   12   15  186
#  Outer Iter. 21  Inner Iter.  2:  Max. DC =  0.3576E-06  [K,I,J]   12   35  195
#  Outer Iter. 22  Inner Iter.  1:  Max. DC =  0.1073E-05  [K,I,J]   12   77  197
#  Outer Iter. 22  Inner Iter.  2:  Max. DC =  0.1073E-05  [K,I,J]   12   48  200
#  Outer Iter. 22  Inner Iter.  3:  Max. DC =  0.1609E-05  [K,I,J]   12   48  200
#  Outer Iter. 22  Inner Iter.  4:  Max. DC =  0.2384E-06  [K,I,J]   12    1  200
#  Outer Iter. 23  Inner Iter.  1:  Max. DC =  0.1132E-05  [K,I,J]   12   77  196
#  Outer Iter. 23  Inner Iter.  2:  Max. DC =  0.3576E-06  [K,I,J]   11   77  189
#  Outer Iter. 24  Inner Iter.  1:  Max. DC =  0.1073E-05  [K,I,J]   12    9  194
#  Outer Iter. 24  Inner Iter.  2:  Max. DC =  0.8345E-06  [K,I,J]   12   46  165
#  Outer Iter. 25  Inner Iter.  1:  Max. DC =  0.1252E-05  [K,I,J]   12   19  147
#  Outer Iter. 25  Inner Iter.  2:  Max. DC =  0.8941E-06  [K,I,J]   12   22  177
#  Outer Iter. 26  Inner Iter.  1:  Max. DC =  0.1490E-05  [K,I,J]   12   97  174
#  Outer Iter. 26  Inner Iter.  2:  Max. DC =  0.3099E-05  [K,I,J]   12   97  197
#  Outer Iter. 26  Inner Iter.  3:  Max. DC =  0.2384E-05  [K,I,J]   12   97  197
#  Outer Iter. 26  Inner Iter.  4:  Max. DC =  0.1192E-06  [K,I,J]    7   91  190
#  Outer Iter. 27  Inner Iter.  1:  Max. DC =  0.1371E-05  [K,I,J]   12   36  180
#  Outer Iter. 27  Inner Iter.  2:  Max. DC =  0.1788E-06  [K,I,J]   12   22  184
#  Outer Iter. 28  Inner Iter.  1:  Max. DC =  0.1073E-05  [K,I,J]   12   97  172
#  Outer Iter. 28  Inner Iter.  2:  Max. DC =  0.1192E-06  [K,I,J]   12    5  198
#  Outer Iter. 29  Inner Iter.  1:  Max. DC =  0.9537E-06  [K,I,J]   11   18  188
#
#  Program completed.   Total CPU time:  000 minutes  5.766 seconds
# Transport model has been run
# Case study: 1
# Flow model name: TB_01_R1_CS1
# Transport model name: TB_01_mt3d_R1_CS1
# Discretisation module set up
# Setting up hk array for Case Study 1
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 2
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R1_CS1.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   9664.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   750.7      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5020E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6972E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2798E+06  [K,I,J]   12   60  104
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2648E+06  [K,I,J]   12   59  104
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3545E+06  [K,I,J]   12   58  104
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1125E+06  [K,I,J]   12   59  105
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2355E+06  [K,I,J]   12   58  105
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6223E+05  [K,I,J]   12   58  105
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1270E+06  [K,I,J]    1   59  105
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.9950E+05  [K,I,J]   12   59  106
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1308E+06  [K,I,J]   12   58  105
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1428E+06  [K,I,J]   12   58  105
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.7260E+05  [K,I,J]    1   60  107
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.4828E+05  [K,I,J]    1   60  107
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =   7291.      [K,I,J]   12   70  109
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =   8901.      [K,I,J]    1   59  107
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =   3952.      [K,I,J]   12   66  109
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =   5454.      [K,I,J]    1   60  108
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.1576E+05  [K,I,J]    1   64  109
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.2696E+05  [K,I,J]    1   60  108
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.3977E+05  [K,I,J]    1   60  108
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =   1146.      [K,I,J]   12   65  110
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =   240.3      [K,I,J]   12   65  110
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =   875.2      [K,I,J]   12   65  110
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =   4830.      [K,I,J]   12   64  111
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =   4667.      [K,I,J]   12   64  111
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =   1662.      [K,I,J]   12   65  111
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =   999.7      [K,I,J]   12   65  111
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =   752.8      [K,I,J]   12   65  111
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =   160.7      [K,I,J]   12   64  112
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =   410.8      [K,I,J]   12   76  149
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =   428.2      [K,I,J]   12   76  149
#  Outer Iter.  1  Inner Iter. 35:  Max. DC =   178.4      [K,I,J]   12   76  149
#  Outer Iter.  1  Inner Iter. 36:  Max. DC =   46.19      [K,I,J]   12   75  153
#  Outer Iter.  1  Inner Iter. 37:  Max. DC =   9.810      [K,I,J]   12   64  112
#  Outer Iter.  1  Inner Iter. 38:  Max. DC =   49.55      [K,I,J]   12   75  152
#  Outer Iter.  1  Inner Iter. 39:  Max. DC =   22.19      [K,I,J]   12   73  154
#  Outer Iter.  1  Inner Iter. 40:  Max. DC =   51.19      [K,I,J]   12   74  155
#  Outer Iter.  1  Inner Iter. 41:  Max. DC =   157.7      [K,I,J]   12   74  153
#  Outer Iter.  1  Inner Iter. 42:  Max. DC =   39.74      [K,I,J]   12   74  152
#  Outer Iter.  1  Inner Iter. 43:  Max. DC =   7.036      [K,I,J]   12   73  155
#  Outer Iter.  1  Inner Iter. 44:  Max. DC =   20.68      [K,I,J]   12   74  154
#  Outer Iter.  1  Inner Iter. 45:  Max. DC =   21.83      [K,I,J]   12   74  154
#  Outer Iter.  1  Inner Iter. 46:  Max. DC =   22.71      [K,I,J]   12   74  154
#  Outer Iter.  1  Inner Iter. 47:  Max. DC =  0.3120      [K,I,J]   12   72  157
#  Outer Iter.  1  Inner Iter. 48:  Max. DC =  0.6294      [K,I,J]   12   73  155
#  Outer Iter.  1  Inner Iter. 49:  Max. DC =  0.7783      [K,I,J]   12   72  154
#  Outer Iter.  1  Inner Iter. 50:  Max. DC =  0.4087      [K,I,J]   12   75  151
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.6233E-02  [K,I,J]   12   57    1
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.8823E-02  [K,I,J]   12   57    1
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.7416E-02  [K,I,J]   12   57    1
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.3122E-03  [K,I,J]    9   76  104
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.6989E-02  [K,I,J]    1   70  105
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.3352E-02  [K,I,J]    9   69  106
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.1638E-01  [K,I,J]    1   68  106
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.1115E-01  [K,I,J]    1   67  107
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.7031E-02  [K,I,J]    1   70  106
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.1544E-01  [K,I,J]    1   68  106
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.1035E-01  [K,I,J]    1   69  107
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.8576E-02  [K,I,J]    1   69  107
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =   1.825      [K,I,J]    1   67  108
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =   1.833      [K,I,J]    1   67  108
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.3912E-02  [K,I,J]    1   67  108
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.7199E-03  [K,I,J]   11   65  108
#  Outer Iter.  2  Inner Iter. 17:  Max. DC =  0.6206E-03  [K,I,J]    1   65  109
#  Outer Iter.  2  Inner Iter. 18:  Max. DC =  0.8312E-03  [K,I,J]    1   65  109
#  Outer Iter.  2  Inner Iter. 19:  Max. DC =  0.1395E-02  [K,I,J]    1   69  108
#  Outer Iter.  2  Inner Iter. 20:  Max. DC =  0.1347E-02  [K,I,J]    1   68  108
#  Outer Iter.  2  Inner Iter. 21:  Max. DC =  0.1167E-02  [K,I,J]    1   66  108
#  Outer Iter.  2  Inner Iter. 22:  Max. DC =  0.7885E-03  [K,I,J]   11   65  108
#  Outer Iter.  2  Inner Iter. 23:  Max. DC =  0.1686E-03  [K,I,J]    1   70  107
#  Outer Iter.  2  Inner Iter. 24:  Max. DC =  0.4273E-03  [K,I,J]    1   66  109
#  Outer Iter.  2  Inner Iter. 25:  Max. DC =  0.8651E-03  [K,I,J]    1   65  109
#  Outer Iter.  2  Inner Iter. 26:  Max. DC =  0.1876E-02  [K,I,J]    1   68  106
#  Outer Iter.  2  Inner Iter. 27:  Max. DC =  0.3982E-02  [K,I,J]    1   68  106
#  Outer Iter.  2  Inner Iter. 28:  Max. DC =  0.2544E-02  [K,I,J]    1   68  106
#  Outer Iter.  2  Inner Iter. 29:  Max. DC =  0.4771E-03  [K,I,J]    1   69  106
#  Outer Iter.  2  Inner Iter. 30:  Max. DC =  0.6411E-02  [K,I,J]    1   68  106
#  Outer Iter.  2  Inner Iter. 31:  Max. DC =  0.2937E-01  [K,I,J]    1   68  106
#  Outer Iter.  2  Inner Iter. 32:  Max. DC =  0.9484E-02  [K,I,J]    1   68  106
#  Outer Iter.  2  Inner Iter. 33:  Max. DC =  0.1475E-02  [K,I,J]    1   72  105
#  Outer Iter.  2  Inner Iter. 34:  Max. DC =  0.8616E-03  [K,I,J]    1   67  107
#  Outer Iter.  2  Inner Iter. 35:  Max. DC =  0.9472E-03  [K,I,J]    1   65  109
#  Outer Iter.  2  Inner Iter. 36:  Max. DC =  0.3757E-03  [K,I,J]    1   65  109
#  Outer Iter.  2  Inner Iter. 37:  Max. DC =  0.1096E-02  [K,I,J]    1   65  109
#  Outer Iter.  2  Inner Iter. 38:  Max. DC =  0.1301E-02  [K,I,J]    1   72  105
#  Outer Iter.  2  Inner Iter. 39:  Max. DC =  0.4249E-02  [K,I,J]   11   71  105
#  Outer Iter.  2  Inner Iter. 40:  Max. DC =  0.1554E-01  [K,I,J]    1   66  110
#  Outer Iter.  2  Inner Iter. 41:  Max. DC =  0.3130E-02  [K,I,J]    1   66  110
#  Outer Iter.  2  Inner Iter. 42:  Max. DC =  0.3685      [K,I,J]    1   65  110
#  Outer Iter.  2  Inner Iter. 43:  Max. DC =  0.3965      [K,I,J]    1   65  110
#  Outer Iter.  2  Inner Iter. 44:  Max. DC =  0.2562E-02  [K,I,J]   11   71  105
#  Outer Iter.  2  Inner Iter. 45:  Max. DC =  0.1028E-02  [K,I,J]    1   65  111
#  Outer Iter.  2  Inner Iter. 46:  Max. DC =  0.2906E-04  [K,I,J]    1   66  111
#  Outer Iter.  2  Inner Iter. 47:  Max. DC =  0.1602E-02  [K,I,J]    1   67  111
#  Outer Iter.  2  Inner Iter. 48:  Max. DC =  0.1663E-02  [K,I,J]    1   64  110
#  Outer Iter.  2  Inner Iter. 49:  Max. DC =  0.1602E-02  [K,I,J]    1   67  112
#  Outer Iter.  2  Inner Iter. 50:  Max. DC =  0.2834E-02  [K,I,J]    1   63  111
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.1039E-01  [K,I,J]    1   64  111
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.3025E-02  [K,I,J]   11   63  112
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.1404E-02  [K,I,J]    1   65  111
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.1049E-02  [K,I,J]    1   65  111
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.4970E-04  [K,I,J]    1   65  109
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.1793E-04  [K,I,J]    1   65  109
#  Outer Iter.  3  Inner Iter.  7:  Max. DC =  0.2639E-03  [K,I,J]    1   65  109
#  Outer Iter.  3  Inner Iter.  8:  Max. DC =  0.1844E-03  [K,I,J]    1   64  110
#  Outer Iter.  3  Inner Iter.  9:  Max. DC =  0.2837E-04  [K,I,J]   12   73  153
#  Outer Iter.  3  Inner Iter. 10:  Max. DC =  0.2574E-03  [K,I,J]   12   72  162
#  Outer Iter.  3  Inner Iter. 11:  Max. DC =  0.2097E-03  [K,I,J]   12   72  162
#  Outer Iter.  3  Inner Iter. 12:  Max. DC =  0.2986E-04  [K,I,J]   12   70  152
#  Outer Iter.  3  Inner Iter. 13:  Max. DC =  0.1677E-03  [K,I,J]   12   69  151
#  Outer Iter.  3  Inner Iter. 14:  Max. DC =  0.3213E-04  [K,I,J]   12   67  169
#  Outer Iter.  3  Inner Iter. 15:  Max. DC =  0.8118E-04  [K,I,J]   12   71  160
#  Outer Iter.  3  Inner Iter. 16:  Max. DC =  0.1523E-04  [K,I,J]    1   62  112
#  Outer Iter.  3  Inner Iter. 17:  Max. DC =  0.2086E-04  [K,I,J]   12   71  156
#  Outer Iter.  3  Inner Iter. 18:  Max. DC =  0.1872E-04  [K,I,J]   12   66  200
#  Outer Iter.  3  Inner Iter. 19:  Max. DC =  0.1544E-04  [K,I,J]   12   67  162
#  Outer Iter.  3  Inner Iter. 20:  Max. DC =  0.1144E-04  [K,I,J]   12   67  155
#  Outer Iter.  3  Inner Iter. 21:  Max. DC =  0.1913E-04  [K,I,J]   12   67  156
#  Outer Iter.  3  Inner Iter. 22:  Max. DC =  0.7212E-05  [K,I,J]   12   64  200
#  Outer Iter.  3  Inner Iter. 23:  Max. DC =  0.6735E-05  [K,I,J]   12   64  200
#  Outer Iter.  3  Inner Iter. 24:  Max. DC =  0.1371E-05  [K,I,J]   12   62  200
#  Outer Iter.  3  Inner Iter. 25:  Max. DC =  0.4172E-06  [K,I,J]   12   61  196
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.4005E-04  [K,I,J]   11   70  113
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.1439E-04  [K,I,J]   11   68  114
#  Outer Iter.  4  Inner Iter.  3:  Max. DC =  0.6974E-05  [K,I,J]    1   63  113
#  Outer Iter.  4  Inner Iter.  4:  Max. DC =  0.5126E-05  [K,I,J]   11   63  115
#  Outer Iter.  4  Inner Iter.  5:  Max. DC =  0.2384E-06  [K,I,J]    7   66  113
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.8345E-06  [K,I,J]   12   54  200
#
#  Program completed.   Total CPU time:  000 minutes  4.375 seconds
# Transport model has been run
# Case study: 2
# Flow model name: TB_01_R1_CS2
# Transport model name: TB_01_mt3d_R1_CS2
# Discretisation module set up
# Setting up hk array for Case Study 2
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 2
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R1_CS2.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   9990.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2533E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =   9382.      [K,I,J]    9  100  101
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3983E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1598E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =   2101.      [K,I,J]   10  100  101
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =   6539.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =   2058.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =   758.8      [K,I,J]   10  100  101
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =   57.78      [K,I,J]    8  100  101
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =   47.79      [K,I,J]    7   99  101
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =   5.266      [K,I,J]    8  100  101
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.7314      [K,I,J]    5  100  101
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6265      [K,I,J]    7  100  101
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.5107      [K,I,J]    8  100  101
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1528      [K,I,J]    8  100  101
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.2002E-01  [K,I,J]    6  100  101
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.2783E-01  [K,I,J]   12   99  189
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1133      [K,I,J]    6  100  101
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.8887E-01  [K,I,J]    6  100  101
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.4883E-02  [K,I,J]    6  100  101
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.4883E-03  [K,I,J]    7  100  101
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.1825E-01  [K,I,J]    7   35  101
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.5504E-02  [K,I,J]    6  100  101
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.2813E-02  [K,I,J]    6  100  101
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.2672E-02  [K,I,J]   11   99  101
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.4046E-03  [K,I,J]   10  100  101
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.5789E-03  [K,I,J]   10  100  101
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.4174E-03  [K,I,J]   10  100  101
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.5937E-04  [K,I,J]    6   46  101
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.1593E-03  [K,I,J]   12   99  200
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.7915E-04  [K,I,J]   12   99  194
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.2503E-05  [K,I,J]   11    1  200
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.1323E-04  [K,I,J]   11   44  200
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.3278E-05  [K,I,J]   11   35  200
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.5364E-06  [K,I,J]   11    1  200
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.4517E-03  [K,I,J]    7   98  101
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.1207E-03  [K,I,J]    8   41  101
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.6407E-04  [K,I,J]   12   99  156
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.1794E-04  [K,I,J]   12   99  200
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.1073E-04  [K,I,J]   12   99  150
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.4262E-04  [K,I,J]   12   72  200
#  Outer Iter.  3  Inner Iter.  7:  Max. DC =  0.6676E-05  [K,I,J]   12    7  200
#  Outer Iter.  3  Inner Iter.  8:  Max. DC =  0.1550E-05  [K,I,J]   11  100  101
#  Outer Iter.  3  Inner Iter.  9:  Max. DC =  0.5960E-06  [K,I,J]   11    1  101
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.1198E-04  [K,I,J]    8   68  101
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.3755E-05  [K,I,J]    8   52  101
#  Outer Iter.  4  Inner Iter.  3:  Max. DC =  0.1073E-05  [K,I,J]   12    6  168
#  Outer Iter.  4  Inner Iter.  4:  Max. DC =  0.1192E-05  [K,I,J]   12    6  200
#  Outer Iter.  4  Inner Iter.  5:  Max. DC =  0.1192E-06  [K,I,J]   12    5  200
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.1431E-05  [K,I,J]   10   46  196
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.1013E-05  [K,I,J]   11   61  101
#  Outer Iter.  5  Inner Iter.  3:  Max. DC =  0.3576E-06  [K,I,J]    9   73  101
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.1013E-05  [K,I,J]   10   28  199
#  Outer Iter.  6  Inner Iter.  2:  Max. DC =  0.3576E-06  [K,I,J]   11   53  101
#  Outer Iter.  7  Inner Iter.  1:  Max. DC =  0.1013E-05  [K,I,J]   12  100  200
#  Outer Iter.  7  Inner Iter.  2:  Max. DC =  0.2980E-06  [K,I,J]   11   14  101
#  Outer Iter.  8  Inner Iter.  1:  Max. DC =  0.9537E-06  [K,I,J]   11   79  196
#
#  Program completed.   Total CPU time:  000 minutes  3.016 seconds
# Transport model has been run
# Finished running all scenarios
# Total run time: 86.35111498832703seconds

# %% [markdown]
# # Plotting results
#
# To do this I set up "databases" with dictionaries within which to save the results
#
# ## Database set up

# %%
headDict = {}
ageDict = {}
massDict = {}

diffHeadAbsDict = {} # Absolute difference in head barrier/non-barrier
diffHeadRelDict = {} # Relative difference in head barrier/non-barrier

diffAgeAbsDict = {} # Absolute difference in age barrier/non-barrier
diffAgeRelDict = {} # Relative difference in age barrier/non-barrier

gammaHeadDict = {}
gammaAgeDict = {}

prctDiffHeadDict = {} # Percent change in head with barrier compared to without 
prctDiffAgeDict = {} # Percent change in age with barrier compared to without 

statsDict = {}

modelObjectDict = {}

cellBudgetDict = {}
frfDict = {} # Flow right face
fffDict = {} # Flow front face
flfDict = {} # Flow left face

nodeCoordsDict = {}

# %% [markdown]
# ### Create the keys for the dictionary

# %%
rechargeScenarioNames = [] 
for i in range(number_of_recharge_scenarios):
    rechargeScenarioNames.append('RECHARGE_%i'%i)
print(rechargeScenarioNames)

caseStudyNames = []
for i in range(number_of_casestudies):
    caseStudyNames.append('CS_%i'%i)
print(caseStudyNames)
# Out:
# ['RECHARGE_0', 'RECHARGE_1']
# ['CS_0', 'CS_1', 'CS_2']

# %% [markdown]
# ### Make a dictionary with head files for each recharge scenario and case study

# %%
for rechargeScenario in range(number_of_recharge_scenarios): # number_of_recharge_scenarios
    headDict[rechargeScenarioNames[rechargeScenario]] = {}
    ageDict[rechargeScenarioNames[rechargeScenario]] = {}
    massDict[rechargeScenarioNames[rechargeScenario]] = {}
    modelObjectDict[rechargeScenarioNames[rechargeScenario]] = {}
    cellBudgetDict[rechargeScenarioNames[rechargeScenario]] = {}
    frfDict[rechargeScenarioNames[rechargeScenario]] = {}
    fffDict[rechargeScenarioNames[rechargeScenario]] = {}
    flfDict[rechargeScenarioNames[rechargeScenario]] = {}
    nodeCoordsDict[rechargeScenarioNames[rechargeScenario]] = {}

    for caseStudy in range(number_of_casestudies): #number_of_casestudies

        modelname = modelName
        modelname_mt3d = modelName_mt3d
        modelname = (str(modelname) + "_R" + str(rechargeScenario) 
        + "_CS" + str(caseStudy))
        modelname_mt3d = (modelname_mt3d + "_R" + str(rechargeScenario) 
        + "_CS" + str(caseStudy))
       
        # HEADFILES - FROM FLOW MODEL
        headobj = bf.HeadFile(modelname + '.hds')
        head_times = headobj.get_times()
        head_raster = headobj.get_data(totim=head_times[0])
        headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = head_raster

        # CONCENTRATION/AGE FILES - FROM TRANSPORT MODEL
        directage_file = modelname_mt3d + str('.ucn') 
        ucnobjc_direct_age = flopy.utils.binaryfile.UcnFile(directage_file, precision=model_precision)
        age_times = ucnobjc_direct_age.get_times()
        age_raster = ucnobjc_direct_age.get_data(totim=age_times[0])
        ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = age_raster
        
        # MASS BUDGET FILES - FROM TRANSPORT MODEL
        mass_file = modelname_mt3d + str('.mas') 
        mas = flopy.mt3d.Mt3dms.load_mas(mass_file)
        massDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = mas

        # MODEL OBJECTS (USE FOR X-SECTN PLOTS) - FROM FLOW MODEL
        ml = flopy.modflow.Modflow.load(str(modelname) + ".nam")
        modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = ml
        node_coordinates = ml.dis.get_node_coordinates()
        nodeCoordsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = node_coordinates

        # CELL BUDGET FILES WHICH I CAN USE TO DRAW VELOCITY ARROWS ON MY PLOTS
        cbb = bf.CellBudgetFile(modelname+'.cbc', precision=model_precision)
        cellBudgetDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = cbb

        frf = cbb.get_data(text='FLOW RIGHT FACE', totim=head_times[0])[0]
        frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = frf
        fff = cbb.get_data(text='FLOW FRONT FACE', totim=head_times[0])[0]
        fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = fff
        flf = cbb.get_data(text='FLOW LOWER FACE', totim=head_times[0])[0]
        flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = flf

# %% [markdown]
# ### Have a look at what one of these datasets looks like

# %%
print(headDict.keys())
print(type(headDict['RECHARGE_0']))
print(headDict['RECHARGE_0'].keys())
print(type(headDict['RECHARGE_0']['CS_0']))
print(headDict['RECHARGE_0']['CS_0'].shape)
# Out:
# dict_keys(['RECHARGE_0', 'RECHARGE_1'])
# <class 'dict'>
# dict_keys(['CS_0', 'CS_1', 'CS_2'])
# <class 'numpy.ndarray'>
# (12, 100, 200)

# %% [markdown]
# ### Make arrays for age and head: difference between case studies

# %%
for rechargeScenario in range(number_of_recharge_scenarios):
    diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]] = {}
    diffHeadRelDict[rechargeScenarioNames[rechargeScenario]] = {}
    diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]] = {}
    diffAgeRelDict[rechargeScenarioNames[rechargeScenario]] = {}
    
    for caseStudy in range(number_of_casestudies): 
        
        (diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]]   
         [caseStudyNames[caseStudy]]) = ((headDict[rechargeScenarioNames[rechargeScenario]]
         [caseStudyNames[caseStudy]]) - (headDict[rechargeScenarioNames[rechargeScenario]]
         [caseStudyNames[0]]))

        diffHeadRelDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = ((headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] - headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]])/headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]])

        (diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]]
         [caseStudyNames[caseStudy]]) = ((ageDict[rechargeScenarioNames[rechargeScenario]]
         [caseStudyNames[caseStudy]]) - (ageDict[rechargeScenarioNames[rechargeScenario]]
         [caseStudyNames[0]]))

        diffAgeRelDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = ((ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] - ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]])/ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]])

# %% [markdown]
# ### Making arrays for the normalised difference in age
#
# Adapted from metric in Zinn and Konikow ()

# %%
for rechargeScenario in range(number_of_recharge_scenarios):
    gammaAgeDict[rechargeScenarioNames[rechargeScenario]] = {}
    gammaHeadDict[rechargeScenarioNames[rechargeScenario]] = {}
    for caseStudy in range(number_of_casestudies): 
        gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = np.ones((nlay,nrow,ncol),dtype=np.float32)
        gammaHeadDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]] = np.ones((nlay,nrow,ncol),dtype=np.float32)
for rechargeScenario in range(number_of_recharge_scenarios):
    for caseStudy in range(number_of_casestudies): 
        for il in range(nlay): #nlay
            for ir in range(nrow): #nrow
                for ic in range(ncol): #ncol                 
                    age_with_barr = ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][il][ir, ic]
                    age_no_barr = ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]][il][ir, ic]                       
                    
                    head_with_barr = headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][il][ir, ic]
                    head_no_barr = headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]][il][ir, ic]                       
                    
                    if diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][il][ir, ic] >= 0:
                        gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][il][ir, ic] = (age_with_barr-age_no_barr)/age_no_barr
                        gammaHeadDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][il][ir, ic] = (head_with_barr-head_no_barr)/head_no_barr
                    else:
                        gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][il][ir, ic] = (age_with_barr-age_no_barr)/age_with_barr
                        gammaHeadDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][il][ir, ic] = (head_with_barr-head_no_barr)/head_with_barr

# %% [markdown]
# ## Calculate key statistics

# %%
for rechargeScenario in range(number_of_recharge_scenarios):    
    statsDict[rechargeScenarioNames[rechargeScenario]] = pd.DataFrame({

# Head
    'max_head': [
    np.amax(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amax(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amax(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

    'min_head': [
    np.amin(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amin(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amin(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

    'mean_head': [
    np.mean(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.mean(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.mean(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],
            
    'std_head': [
    np.std(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.std(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.std(headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

# Age
    'max_age': [
    np.amax(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amax(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amax(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

    'min_age': [
    np.amin(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amin(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amin(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

    'mean_age': [
    np.mean(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.mean(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.mean(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],
            
    'std_age': [
    np.std(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.std(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.std(ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

# Abs difference head                        
    'max_diff_head_abs': [
    np.amax(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amax(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amax(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])], 

    'mean_diff_head_abs': [
    np.mean(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.mean(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.mean(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],  

    'std_diff_head_abs': [
    np.std(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.std(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.std(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],    

    'min_diff_head_abs': [
    np.min(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.min(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.min(diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],                  

# Relative difference head                        
    'max_diff_head_rel': [
    np.amax(diffHeadRelDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amax(diffHeadRelDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amax(diffHeadRelDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],                       

# Abs difference age                        
    'max_diff_age_abs': [
    np.amax(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amax(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amax(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],        
    
    'min_diff_age_abs': [
    np.amin(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amin(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amin(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],   
            
    'mean_diff_age_abs': [
    np.mean(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.mean(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.mean(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],
            
    'std_diff_age_abs': [
    np.std(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.std(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.std(diffAgeAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

# Relative difference age                        
    'max_diff_age_rel': [
    np.amax(diffAgeRelDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amax(diffAgeRelDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amax(diffAgeRelDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

# Gamma age
    'max_diff_age_gamma': [
    np.amax(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amax(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amax(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],
            
    'mean_diff_age_gamma': [
    np.mean(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.mean(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.mean(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],
            
    'std_diff_age_gamma': [
    np.std(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.std(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.std(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

    'min_diff_age_gamma': [
    np.amin(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amin(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amin(gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

# Gamma head
    'max_diff_head_gamma': [
    np.amax(gammaHeadDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amax(gammaHeadDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amax(gammaHeadDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])],

    'min_diff_head_gamma': [
    np.amin(gammaHeadDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[0]]),
    np.amin(gammaHeadDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[1]]),
    np.amin(gammaHeadDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[2]])]
    }, index = ["CS_0", "CS_1", "CS_2"])

# %% [markdown]
# # Plotting
#
# ## Figure 3 (CASE STUDY 0)
#
# Fig. 3 Baseline results with uniform recharge (a–b) and upgradient recharge (c–d) shown as a cross-section taken through the centre of the y axis of the model. Results show hydraulic head distributions (a, c) and groundwater age distributions (b, d). The arrows (a, c) indicate groundwater
# flow direction with their length scaled arithmetically by the groundwater velocity.

# %%
# These values are to display on the plots
mean_a = (statsDict[rechargeScenarioNames[0]].loc["CS_0", "mean_head"])
mean_b = int(statsDict[rechargeScenarioNames[0]].loc["CS_0", "mean_age"])
mean_c = (statsDict[rechargeScenarioNames[1]].loc["CS_0", "mean_head"])
mean_d = int(statsDict[rechargeScenarioNames[1]].loc["CS_0", "mean_age"])
std_a = (statsDict[rechargeScenarioNames[0]].loc["CS_0", "std_head"])
std_b = int(statsDict[rechargeScenarioNames[0]].loc["CS_0", "std_age"])
std_c = (statsDict[rechargeScenarioNames[1]].loc["CS_0", "std_head"])
std_d = int(statsDict[rechargeScenarioNames[1]].loc["CS_0", "std_age"])

#==================================
fig = plt.figure(figsize = (10, 7))
#===================================

# # # Recharge Scenario 1: Head
caseStudy = 0
rechargeScenario = 0
ax1 = fig.add_subplot(4, 1, 1)

qx_avg = np.empty(frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qx_avg[:, :, 1:] = 0.5 * (frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0:ncol-1] + 
                            frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 1:ncol])
qx_avg[:, :, 0] = 0.5 * frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0]


qz_avg = np.empty(flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qz_avg[1:, :, :] = 0.5 * (flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0:nlay-1, :, :] + 
                    flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][1:nlay, :, :])
qz_avg[0, :, :] = 0.5 * flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0, :, :]


ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img1 = ax1.imshow(np.flipud(raster), cmap=head_cmap, extent=extent, aspect=5, vmin = head_min, vmax = head_max) # 
axes1 = plt.gca()
axes1.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes1.get_xaxis().set_visible(False)

y, x, z = nodeCoordsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
X, Z = np.meshgrid(x, z[:, 0, 0])

plt.quiver(X[::iskipLayers, ::iskipCols], Z[::iskipLayers, ::iskipCols],
           colDisMultiplyer*qx_avg[::iskipLayers, row_cross_section, ::iskipCols], 
            layerDisMultiplyer*(-qz_avg[::iskipLayers, row_cross_section, ::iskipCols]),
           color='w', scale=5, headwidth=3, headlength=2,
           headaxislength=2, width=0.0025)


# # # Recharge Scenario 1: Age

ax2 = fig.add_subplot(4, 1, 2)
ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img2 = ax2.imshow(np.flipud(raster), cmap=age_cmap, extent=extent, aspect=5, vmin = age_min, vmax = age_max) # 

cs = plt.contour(raster, levels=levels, extent=extent, colors=contour_colors) 
plt.clabel(cs, inline=1, fontsize=10, fmt='%1i', colors=contour_colors)

axes2 = plt.gca()
axes2.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes2.get_xaxis().set_visible(False)

# # # Recharge Scenario 2: Head

caseStudy = 0
rechargeScenario = 1
ax3 = fig.add_subplot(4, 1, 3)

qx_avg = np.empty(frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qx_avg[:, :, 1:] = 0.5 * (frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0:ncol-1] + 
                            frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 1:ncol])
qx_avg[:, :, 0] = 0.5 * frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0]

qz_avg = np.empty(flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qz_avg[1:, :, :] = 0.5 * (flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0:nlay-1, :, :] + 
                    flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][1:nlay, :, :])
qz_avg[0, :, :] = 0.5 * flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0, :, :]

ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img3 = ax3.imshow(np.flipud(raster), cmap=head_cmap, extent=extent, aspect=5) # , vmin = head_min, vmax = head_max
axes3 = plt.gca()
axes3.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes3.get_xaxis().set_visible(False)

y, x, z = nodeCoordsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
X, Z = np.meshgrid(x, z[:, 0, 0])

plt.quiver(X[::iskipLayers, ::iskipCols], Z[::iskipLayers, ::iskipCols],
           colDisMultiplyer*qx_avg[::iskipLayers, row_cross_section, ::iskipCols], 
            layerDisMultiplyer*(-qz_avg[::iskipLayers, row_cross_section, ::iskipCols]),
           color='w', scale=5, headwidth=3, headlength=2,
           headaxislength=2, width=0.0025)


# # # Recharge Scenario 2: Age

ax4 = fig.add_subplot(4, 1, 4)
ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img4 = ax4.imshow(np.flipud(raster), cmap=age_cmap, extent=extent, aspect=5, vmin = age_min, vmax = age_max)# 


#print(get ready for manual contour labels)
cs = plt.contour(raster, levels=levels_2, extent=extent, colors=contour_colors) 
plt.clabel(cs, inline=1, manual = manual_plot, fontsize=10, fmt='%1i', colors=contour_colors)

axes4 = plt.gca()
axes4.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
plt.xlabel('$x$ [m]')

# Adding colour-bars

plt.subplots_adjust(bottom=0.2)

cbaxes1 = fig.add_axes([0.133, 0.1, 0.35, 0.03]) 
cb1 = plt.colorbar(img1, cax = cbaxes1, orientation="horizontal")  
cb1.set_label('Hydraulic head [m]')
tick_locator = ticker.MaxNLocator(nbins = 5)
cb1.locator = tick_locator
cb1.update_ticks()

cbaxes2 = fig.add_axes([0.533, 0.1, 0.35, 0.03]) 
cb2 = plt.colorbar(img2, cax = cbaxes2, orientation="horizontal")  
cb2.set_label('Age [y]')
cb2.locator = tick_locator
cb2.update_ticks()

# Adding text to indicate which recharge scenario
bbox_props = {'facecolor':'white', 'alpha':0.75, 'lw':0}
axes1.text(7500, 200, (r"$\mu$ = %.0f, $\sigma$ = %.2f" % (mean_a, std_a)),
           bbox=bbox_props)
axes2.text(7500, 200, (r"$\mu$ = " + str(mean_b) + r", $\sigma$ = " +str(std_b)),
           bbox=bbox_props)
axes3.text(7500, 200, (r"$\mu$ = %.0f, $\sigma$ = %.2f" % (mean_c, std_c)),
           bbox=bbox_props)
axes4.text(7500, 200, (r"$\mu$ = " + str(mean_d) + r", $\sigma$ = " +str(std_d)),
           bbox=bbox_props)

gap_amount = .146

# Use position values for the text, i.e. (x, (y + height), ...
plt.gcf().text(0.125, (0.7544685976449275+gap_amount), "(a) Hydraulic head, Uniform recharge")
plt.gcf().text(0.125, (0.5718599019927537+gap_amount), "(b) Groundwater age, Uniform recharge")
plt.gcf().text(0.125, (0.3892512063405797+gap_amount), "(c) Hydraulic head, Upgradient recharge")
plt.gcf().text(0.125, (0.20664251068840572+gap_amount), "(d) Groundwater age, Upgradient recharge")

# Saving the plot
name = "fig_3"
plt.savefig(os.path.join(figureDirectory, name), dpi = dpi_value)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)

# %% [markdown]
# ## Figure 4 (CASE STUDY 1)
#
# Fig. 4 Fully-penetrating barrier results with uniform recharge (a–c) and upgradient recharge (d–f),
# shown as a cross-section taken through the centre of the y axis of the model. Results show hydraulic
# head distributions (a, d); groundwater age distributions (b, e); and normalised differences in
# groundwater age (c, f). The arrows on (a) and (d) indicate groundwater flow direction with their length scaled arithmetically by the groundwater velocity.

# %%
mean_a = (statsDict[rechargeScenarioNames[0]].loc["CS_1", "mean_head"])
mean_b = int(statsDict[rechargeScenarioNames[0]].loc["CS_1", "mean_age"])
mean_c = statsDict[rechargeScenarioNames[0]].loc["CS_1", "mean_diff_age_gamma"]
mean_d = (statsDict[rechargeScenarioNames[1]].loc["CS_1", "mean_head"])
mean_e = int(statsDict[rechargeScenarioNames[1]].loc["CS_1", "mean_age"])
mean_f = statsDict[rechargeScenarioNames[1]].loc["CS_1", "mean_diff_age_gamma"]

std_a = (statsDict[rechargeScenarioNames[0]].loc["CS_1", "std_head"])
std_b = int(statsDict[rechargeScenarioNames[0]].loc["CS_1", "std_age"])
std_c = statsDict[rechargeScenarioNames[0]].loc["CS_1", "std_diff_age_gamma"]
std_d = (statsDict[rechargeScenarioNames[1]].loc["CS_1", "std_head"])
std_e = int(statsDict[rechargeScenarioNames[1]].loc["CS_1", "std_age"])
std_f = statsDict[rechargeScenarioNames[1]].loc["CS_1", "std_diff_age_gamma"]

                    
#==================================
fig = plt.figure(figsize = (10, 12))
#===================================

# # # Recharge Scenario 1: Head
caseStudy = 1
rechargeScenario = 0
ax1 = fig.add_subplot(6, 1, 1)

qx_avg = np.empty(frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qx_avg[:, :, 1:] = 0.5 * (frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0:ncol-1] + 
                            frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 1:ncol])
qx_avg[:, :, 0] = 0.5 * frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0]

qz_avg = np.empty(flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qz_avg[1:, :, :] = 0.5 * (flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0:nlay-1, :, :] + 
                    flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][1:nlay, :, :])
qz_avg[0, :, :] = 0.5 * flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0, :, :]

ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img1 = ax1.imshow(np.flipud(raster), cmap=head_cmap, extent=extent, aspect=5, vmin = head_min, vmax = head_max) # 
axes1 = plt.gca()
axes1.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes1.get_xaxis().set_visible(False)


y, x, z = nodeCoordsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
X, Z = np.meshgrid(x, z[:, 0, 0])

plt.quiver(X[::iskipLayers, ::iskipCols], Z[::iskipLayers, ::iskipCols],
           colDisMultiplyer*qx_avg[::iskipLayers, row_cross_section, ::iskipCols], 
            layerDisMultiplyer*(-qz_avg[::iskipLayers, row_cross_section, ::iskipCols]),
           color='w', scale=6, headwidth=3, headlength=2,
           headaxislength=2, width=0.0025)

# # # Recharge Scenario 1: Age

ax2 = fig.add_subplot(6, 1, 2)
ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img2 = ax2.imshow(np.flipud(raster), cmap=age_cmap, extent=extent, aspect=5, vmin = age_min, vmax = age_max) # 

cs = plt.contour(raster, levels=levels, extent=extent, colors=contour_colors) 
plt.clabel(cs, inline=1, fontsize=10, fmt='%1i', colors=contour_colors)

axes2 = plt.gca()
axes2.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes2.get_xaxis().set_visible(False)

# # # Recharge Scenario 1: Difference in Age (gamma)

# ---
data_3 = gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
sigma = 4.0 # this depends on how noisy your data is, play with it!
filter_3 = gaussian_filter(data_3, sigma)
# ---

gamma_cs_labels_2 = np.linspace(-0.1, 0.1, 21)

ax3 = fig.add_subplot(6, 1, 3)
ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = filter_3
img3 = ax3.imshow(np.flipud(raster), cmap=diff_age_cmap, extent=extent, aspect=5, vmin = gamma_age_min, vmax = gamma_age_max) # 

cs = plt.contour(raster, levels=gamma_cs_labels_2, extent=extent, colors=contour_colors) 
plt.clabel(cs, gamma_cs_labels_2, inline=1, fontsize=10, fmt='%1.2f', colors=contour_colors)

axes3 = plt.gca()
axes3.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes3.get_xaxis().set_visible(False)

# # # Recharge Scenario 2: Head

rechargeScenario = 1
ax4 = fig.add_subplot(6, 1, 4)

qx_avg = np.empty(frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qx_avg[:, :, 1:] = 0.5 * (frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0:ncol-1] + 
                            frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 1:ncol])
qx_avg[:, :, 0] = 0.5 * frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0]

qz_avg = np.empty(flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qz_avg[1:, :, :] = 0.5 * (flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0:nlay-1, :, :] + 
                    flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][1:nlay, :, :])
qz_avg[0, :, :] = 0.5 * flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0, :, :]

ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img4 = ax4.imshow(np.flipud(raster), cmap=head_cmap, extent=extent, aspect=5, vmin = head_min, vmax = head_max) # 
axes4 = plt.gca()
axes4.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes4.get_xaxis().set_visible(False)

y, x, z = nodeCoordsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
X, Z = np.meshgrid(x, z[:, 0, 0])

plt.quiver(X[::iskipLayers, ::iskipCols], Z[::iskipLayers, ::iskipCols],
           colDisMultiplyer*qx_avg[::iskipLayers, row_cross_section, ::iskipCols], 
            layerDisMultiplyer*(-qz_avg[::iskipLayers, row_cross_section, ::iskipCols]),
           color='w', scale=5, headwidth=3, headlength=2,
           headaxislength=2, width=0.0025)

# # # Recharge Scenario 2: Age

ax5 = fig.add_subplot(6, 1, 5)
ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img5 = ax5.imshow(np.flipud(raster), cmap=age_cmap, extent=extent, aspect=5, vmin = age_min, vmax = age_max) 

#print(get ready for manual contour labels)
cs = plt.contour(raster, levels=levels_2, extent=extent, colors=contour_colors) 
plt.clabel(cs, inline=1, manual=manual_plot, fontsize=10, fmt='%1i', colors=contour_colors)

axes5 = plt.gca()
axes5.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes5.get_xaxis().set_visible(False)

# # # Recharge Scenario 2: Gamma difference in age

ax6 = fig.add_subplot(6, 1, 6)
ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img6 = ax6.imshow(np.flipud(raster), cmap=diff_age_cmap, extent=extent, aspect=5, vmin = gamma_age_min, vmax = gamma_age_max) 

#print(get ready for manual contour labels)
cs = plt.contour(raster, levels=gamma_cs_labels, extent=extent, colors=contour_colors) 
plt.clabel(cs, gamma_cs_labels, inline=1, manual=manual_plot, fontsize=10, fmt='%1i', colors=contour_colors)

axes6 = plt.gca()
axes6.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
plt.xlabel('$x$ [m]')

# Adding colour-bars

plt.subplots_adjust(bottom=0.2)

cbaxes1 = fig.add_axes([.1, 0.1, 0.24, 0.03]) 
cb1 = plt.colorbar(img1, cax = cbaxes1, orientation="horizontal")  
cb1.set_label('Hydraulic head [m]')
#tick_locator = ticker.MaxNLocator(nbins = 5)
#cb1.locator = tick_locator
#cb1.update_ticks()

cbaxes2 = fig.add_axes([.38, 0.1, 0.24, 0.03]) 
cb2 = plt.colorbar(img2, cax = cbaxes2, orientation="horizontal")  
cb2.set_label('Age [y]')
cb2.locator = tick_locator
cb2.update_ticks()

cbaxes3 = fig.add_axes([0.66, 0.1, 0.24, 0.03]) 
cb3 = plt.colorbar(img3, cax = cbaxes3, orientation="horizontal")  
#cb3.set_label(r'$\Gamma\rm{^a}$ [-]') #r'$\Gamma^a$ [-]')  u'${\u0413}\\rm{^a}$ [-]'
#cb3.locator = tick_locator
#cb3.update_ticks()

# Adding text to indicate which recharge scenario

bbox_props = {'facecolor':'white', 'alpha':0.75, 'lw':0}
axes1.text(7500, 200, (r"$\mu$ = %.0f, $\sigma$ = %.2f" % (mean_a, std_a)),
           bbox=bbox_props)
axes2.text(7500, 200, (r"$\mu$ = " + str(mean_b) + r", $\sigma$ = " +str(std_b)),
           bbox=bbox_props)
axes3.text(7500, 200, (r"$\mu$ = %.2f, $\sigma$ = %.2f" % (mean_c, std_c)),
           bbox=bbox_props)
axes4.text(7500, 200, (r"$\mu$ = %.0f, $\sigma$ = %.2f" % (mean_d, std_d)),
           bbox=bbox_props)
axes5.text(7500, 200, (r"$\mu$ = " + str(mean_e) + r", $\sigma$ = " +str(std_e)),
           bbox=bbox_props)
axes6.text(7500, 200, (r"$\mu$ = %.2f, $\sigma$ = %.2f" % (mean_f, std_f)),
           bbox=bbox_props)

# Use position values for the text, i.e. (x, (y + height), ...
gap_amount = .086
plt.gcf().text(0.125, (0.8095511474164927+gap_amount), "(a) Hydraulic head, Uniform recharge")
plt.gcf().text(0.125, (0.6895511474164927+gap_amount), "(b) Groundwater age, Uniform recharge")
plt.gcf().text(0.125, (0.5695511474164927+gap_amount), "(c) Groundwater age difference, Uniform recharge")
plt.gcf().text(0.125, (0.4495511474164927+gap_amount), "(d) Hydraulic head, Upgradient recharge")
plt.gcf().text(0.125, (0.3295511474164927+gap_amount), "(e) Groundwater age, Upgradient recharge")
plt.gcf().text(0.125, (0.20955114741649272+gap_amount), "(f) Groundwater age difference, Upgradient recharge")

# Saving the plot
name = "fig_4"
plt.savefig(os.path.join(figureDirectory, name), dpi = dpi_value)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)

# %% [markdown]
# ## Figure 5 (CASE STUDY 1)
#
# Fig. 5 a Hydraulic head difference and b normalised groundwater age difference for the fully-penetrating barrier with uniform recharge, in a plan-view slice through the upper half of the
# z axis (z = 237.5 m). Positive values for both hydraulic head difference and normalised
# groundwater age difference indicate that the value for the barrier scenario is higher than that for the non-barrier scenario. The arrows (b) indicate the groundwater flow direction, with their length scaled arithmetically by groundwater velocity. Contours are shown as solid or dashed black lines where the contour represents a positive or negative value, respectively.

# %%
## ABSOLUTE DIFFERENCE IN HEAD/AGE - Case Study 1
# Uniform recharge 
min_abs_head_diff = -1.2
max_abs_head_diff = 1.2
min_abs_age_diff = -100
max_abs_age_diff = 100

caseStudy = 1
rechargeScenario = 0
nLayer = 1 

mean_a = (statsDict[rechargeScenarioNames[0]].loc["CS_1", "mean_diff_head_abs"])
mean_b = (statsDict[rechargeScenarioNames[0]].loc["CS_1", "mean_diff_age_gamma"])
std_a = (statsDict[rechargeScenarioNames[0]].loc["CS_1", "std_diff_head_abs"])
std_b = (statsDict[rechargeScenarioNames[0]].loc["CS_1", "std_diff_age_gamma"])

# These values are for colour-bar evaluation purposes only

max_head_plot = [np.amax(diffHeadAbsDict[rechargeScenarioNames[0]][caseStudyNames[caseStudy]][nLayer, :, :]),
       np.amax(diffHeadAbsDict[rechargeScenarioNames[1]][caseStudyNames[caseStudy]][nLayer, :, :])]

max_age_plot = [np.amax(gammaAgeDict[rechargeScenarioNames[0]][caseStudyNames[caseStudy]][nLayer, :, :]),
       np.amax(gammaAgeDict[rechargeScenarioNames[1]][caseStudyNames[caseStudy]][nLayer, :, :])]

min_head_plot = [np.amin(diffHeadAbsDict[rechargeScenarioNames[0]][caseStudyNames[caseStudy]][nLayer, :, :]),
       np.amin(diffHeadAbsDict[rechargeScenarioNames[1]][caseStudyNames[caseStudy]][nLayer, :, :])]

min_age_plot = [np.amin(gammaAgeDict[rechargeScenarioNames[0]][caseStudyNames[caseStudy]][nLayer, :, :]),
       np.amin(gammaAgeDict[rechargeScenarioNames[1]][caseStudyNames[caseStudy]][nLayer, :, :])]


qx_avg = np.empty(frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qx_avg[:, :, 1:] = 0.5 * (frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0:ncol-1] + 
                            frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 1:ncol])
qx_avg[:, :, 0] = 0.5 * frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0]

qy_avg = np.empty(fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)

qy_avg[:, 1:, :] = 0.5 * (fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, 0:nrow-1, :] + 
                    fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, 1:nrow, :])

qy_avg[:, 0, :] = 0.5 * fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, 0, :]               
                          
levels_1 = np.arange(-1.2, 1.2, 0.2)
diff_head_contours = np.linspace(-2, 2, 41)

#==================================
fig = plt.figure(figsize = (7, 7))
#==================================

ax1 = fig.add_subplot(2, 1, 1)
extent = (delr/2., Lx - delr/2., Ly - delc/2., delc/2.)
raster1 = diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][nLayer, :, :]
img1 = ax1.imshow(np.flipud(raster1), cmap=diff_head_cmap, extent=extent, vmin = min_abs_head_diff, vmax = max_abs_head_diff) # 
axes1 = plt.gca()
plt.ylabel("$y$ [m]")
axes1.axes.get_xaxis().set_visible(False)

cs = plt.contour(raster1, levels=diff_head_contours, extent=extent, colors=contour_colors) 
plt.clabel(cs, diff_head_contours, inline=1, manual=manual_plot, fontsize=10, fmt='%1.1f', colors=contour_colors) #   manual = True, 

# -------- AGE PLOT --------- # 
data_2 = gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][nLayer, :, :]
sigma = 4.0 # this depends on how noisy your data is, play with it!
filter_2 = gaussian_filter(data_2, sigma)
# ---

ax2 = fig.add_subplot(2, 1, 2)
extent = (delr/2., Lx - delr/2., Ly - delc/2., delc/2.)
raster2 = filter_2
img2 = ax2.imshow(np.flipud(raster2), cmap=diff_age_cmap, extent=extent, vmin = -0.03, vmax =0.03) # , vmin = gamma_age_min, vmax = gamma_age_max
axes2 = plt.gca()
plt.xlabel("$x$ [m]")
plt.ylabel("$y$ [m]")

cs = plt.contour(raster2, levels=gamma_cs_labels, extent=extent, colors=contour_colors) 
plt.clabel(cs, gamma_cs_labels, manual=manual_plot, inline=1, fontsize=10, fmt='%1i', colors=contour_colors) #  manual=True, 

y, x, z = nodeCoordsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
X, Y = np.meshgrid(x, y)

iskipRows = 20
iskipCols = 20

plt.quiver(X[::iskipRows, ::iskipCols], Y[::iskipRows, ::iskipCols],
           colDisMultiplyer*qx_avg[nLayer, ::iskipRows, ::iskipCols], 
            rowDisMultiplyer*(qy_avg[nLayer, ::iskipRows, ::iskipCols]),
           color='k', scale=5, headwidth=3, headlength=2,
           headaxislength=2, width=0.0025)

# ---------------------------- #
plt.subplots_adjust(bottom=0.21)

cbaxes1 = fig.add_axes([0.133, 0.1, 0.32, 0.03]) 
cb1 = plt.colorbar(img1, cax = cbaxes1, orientation="horizontal", format='%1.1f')  
cb1.set_label(r'$\Delta h$ [m]')
#tick_locator = ticker.MaxNLocator(nbins = 5)
#cb1.locator = tick_locator
#cb1.update_ticks()

cbaxes2 = fig.add_axes([0.547, 0.1, 0.32, 0.03]) 
cb2 = plt.colorbar(img2, cax = cbaxes2, orientation="horizontal", format='%1.2f')  
cb2.set_label(r'$\Gamma\mathrm{^a}$ [-]')
#cb2.locator = tick_locator
#cb2.update_ticks()

axes1.text(500, 1000, (r"$\mu$ = %.2f, $\sigma$ = %.2f" % (mean_a, std_a)),
           bbox=bbox_props)
axes2.text(500, 1000, (r"$\mu$ = %.2f, $\sigma$ = %.2f" % (mean_b, std_b)),
           bbox=bbox_props)

# Add text to the plot to label the plots
pos1 = axes1.get_position() # shows x, y, width, height
pos2 = axes2.get_position()

# Use position values for the text, i.e. (x, (y + height), ...
gap_amount = 0.33
plt.gcf().text(0.19513686463836777, (0.5818181818181819+gap_amount), r"(a) Hydraulic head difference $\Delta h$")
plt.gcf().text(0.19513686463836777, (0.20000000000000018+gap_amount), r"(b) Normalised age difference $\Gamma\mathrm{^a}$")

# Saving the plot
name = "fig_5"
plt.savefig(os.path.join(figureDirectory, name), dpi = dpi_value)

# %% [markdown]
# ## Figure 6  (CASE STUDY 1)
#
# Fig. 6 a Hydraulic head difference and b normalised groundwater age difference for the fully-penetrating barrier with upgradient recharge, in a planview slice through the upper half
# of the z axis (z = 237.5 m). Positive values for both hydraulic head difference and normalised
# groundwater age difference indicate that the value for the barrier scenario is higher than that for the nonbarrier scenario. The arrows (b) indicate the groundwater flow direction, with their length scaled arithmetically by groundwater velocity. Contours are shown as solid or dashed black lines where the contour represents a positive or negative value, respectively.

# %%
# Uniform recharge 
min_abs_head_diff = -2.1
max_abs_head_diff = 2.1

caseStudy = 1
rechargeScenario = 1
nLayer = 2 

mean_a = (statsDict[rechargeScenarioNames[1]].loc["CS_1", "mean_diff_head_abs"])
mean_b = (statsDict[rechargeScenarioNames[1]].loc["CS_1", "mean_diff_age_gamma"])
std_a = (statsDict[rechargeScenarioNames[1]].loc["CS_1", "std_diff_head_abs"])
std_b = (statsDict[rechargeScenarioNames[1]].loc["CS_1", "std_diff_age_gamma"])

levels_1 = np.arange(-1.2, 1.2, 0.2)

#==================================
fig = plt.figure(figsize = (7, 7))
#==================================

diff_head_contours = np.linspace(-2, 2, 41)


qx_avg = np.empty(frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qx_avg[:, :, 1:] = 0.5 * (frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0:ncol-1] + 
                            frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 1:ncol])
qx_avg[:, :, 0] = 0.5 * frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0]

qy_avg = np.empty(fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)

qy_avg[:, 1:, :] = 0.5 * (fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, 0:nrow-1, :] + 
                    fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, 1:nrow, :])

qy_avg[:, 0, :] = 0.5 * fffDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, 0, :]


ax1 = fig.add_subplot(2, 1, 1)
extent = (delr/2., Lx - delr/2., Ly - delc/2., delc/2.)
raster1 = diffHeadAbsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][nLayer, :, :]
img1 = ax1.imshow(np.flipud(raster1), cmap=diff_head_cmap, extent=extent, vmin = min_abs_head_diff, vmax = max_abs_head_diff) # 
axes1 = plt.gca()
plt.ylabel("$y$ [m]")
axes1.axes.get_xaxis().set_visible(False)

cs = plt.contour(raster1, levels=diff_head_contours, extent=extent, colors=contour_colors) 
plt.clabel(cs, diff_head_contours, inline=1, manual=manual_plot, fontsize=10, fmt='%1.1f', colors=contour_colors) #   manual = True, 

# -------- AGE PLOT --------- # 

ax2 = fig.add_subplot(2, 1, 2)
extent = (delr/2., Lx - delr/2., Ly - delc/2., delc/2.)
raster2 = gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][nLayer, :, :]
img2 = ax2.imshow(np.flipud(raster2), cmap=diff_age_cmap, extent=extent, vmin = gamma_age_min, vmax = gamma_age_max) # 
axes2 = plt.gca()
plt.xlabel("$x$ [m]")
plt.ylabel("$y$ [m]")

cs = plt.contour(raster2, levels=gamma_cs_labels, extent=extent, colors=contour_colors) 
plt.clabel(cs, gamma_cs_labels, inline=1, fontsize=10, fmt='%1i', colors=contour_colors) #  manual=True, 

y, x, z = nodeCoordsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
X, Y = np.meshgrid(x, y)

iskipRows = 37
iskipCols = 50

plt.quiver(X[::iskipRows, ::iskipCols], Y[::iskipRows, ::iskipCols],
           colDisMultiplyer*qx_avg[nLayer, ::iskipRows, ::iskipCols], 
            rowDisMultiplyer*(qy_avg[nLayer, ::iskipRows, ::iskipCols]),
           color='k', scale=5, headwidth=3, headlength=2,
           headaxislength=2, width=0.0025)

# ------------------------------ #
plt.subplots_adjust(bottom=0.21)

cbaxes1 = fig.add_axes([0.133, 0.1, 0.32, 0.03]) 
cb1 = plt.colorbar(img1, cax = cbaxes1, orientation="horizontal", format='%1.1f')  
cb1.set_label(r'$\Delta h$ [m]')
tick_locator = ticker.MaxNLocator(nbins = 5)
cb1.locator = tick_locator
cb1.update_ticks()

cbaxes2 = fig.add_axes([0.547, 0.1, 0.32, 0.03]) 
cb2 = plt.colorbar(img2, cax = cbaxes2, orientation="horizontal", format='%1.2f')  
cb2.set_label(r'$\Gamma\mathrm{^a}$ [-]')
cb2.locator = tick_locator
cb2.update_ticks()


axes1.text(500, 1000, (r"$\mu$ = %.2f, $\sigma$ = %.2f" % (mean_a, std_a)),
           bbox=bbox_props)
axes2.text(500, 1000, (r"$\mu$ = %.2f, $\sigma$ = %.2f" % (mean_b, std_b)),
           bbox=bbox_props)


# Add text to the plot to label the plots
pos1 = axes1.get_position() # shows x, y, width, height
pos2 = axes2.get_position()

# Use position values for the text, i.e. (x, (y + height), ...
gap_amount = 0.33
plt.gcf().text(0.19513686463836777, (0.5818181818181819+gap_amount), r"(a) Hydraulic head difference $\Delta h$")
plt.gcf().text(0.19513686463836777, (0.20000000000000018+gap_amount), r"(b) Normalised age difference $\Gamma\mathrm{^a}$")

# Saving the plot
name = "fig_6"
plt.savefig(os.path.join(figureDirectory, name), dpi = dpi_value)

# %% [markdown]
# ## Figure 7 (CASE STUDY 2)
#
# Fig. 7 Buried barrier results with uniform recharge (a–c) and upgradient recharge (d–f), shown
# as a cross-section taken through the centre of the y axis of the model. Results show hydraulic
# head distributions (a, d); groundwater age distributions (b, e); and normalised differences in
# groundwater age (c, f). The arrows (a, d) indicate groundwater flow direction with their length
# scaled arithmetically by the groundwater velocity.

# %%
mean_a = (statsDict[rechargeScenarioNames[0]].loc["CS_2", "mean_head"])
mean_b = int(statsDict[rechargeScenarioNames[0]].loc["CS_2", "mean_age"])
mean_c = statsDict[rechargeScenarioNames[0]].loc["CS_2", "mean_diff_age_gamma"]
mean_d = (statsDict[rechargeScenarioNames[1]].loc["CS_2", "mean_head"])
mean_e = int(statsDict[rechargeScenarioNames[1]].loc["CS_2", "mean_age"])
mean_f = statsDict[rechargeScenarioNames[1]].loc["CS_2", "mean_diff_age_gamma"]

std_a = (statsDict[rechargeScenarioNames[0]].loc["CS_2", "std_head"])
std_b = int(statsDict[rechargeScenarioNames[0]].loc["CS_2", "std_age"])
std_c = statsDict[rechargeScenarioNames[0]].loc["CS_2", "std_diff_age_gamma"]
std_d = (statsDict[rechargeScenarioNames[1]].loc["CS_2", "std_head"])
std_e = int(statsDict[rechargeScenarioNames[1]].loc["CS_2", "std_age"])
std_f = statsDict[rechargeScenarioNames[1]].loc["CS_2", "std_diff_age_gamma"]
            
#==================================
fig = plt.figure(figsize = (10, 12))
#===================================

# # # Recharge Scenario 1: Head
caseStudy = 2
rechargeScenario = 0
ax1 = fig.add_subplot(6, 1, 1)

qx_avg = np.empty(frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qx_avg[:, :, 1:] = 0.5 * (frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0:ncol-1] + 
                            frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 1:ncol])
qx_avg[:, :, 0] = 0.5 * frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0]

qz_avg = np.empty(flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qz_avg[1:, :, :] = 0.5 * (flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0:nlay-1, :, :] + 
                    flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][1:nlay, :, :])
qz_avg[0, :, :] = 0.5 * flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0, :, :]

ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img1 = ax1.imshow(np.flipud(raster), cmap=head_cmap, extent=extent, aspect=5, vmin = head_min, vmax = head_max) # 
axes1 = plt.gca()
axes1.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes1.get_xaxis().set_visible(False)

y, x, z = nodeCoordsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
X, Z = np.meshgrid(x, z[:, 0, 0])

plt.quiver(X[::iskipLayers, ::iskipCols], Z[::iskipLayers, ::iskipCols],
           colDisMultiplyer*qx_avg[::iskipLayers, row_cross_section, ::iskipCols], 
            layerDisMultiplyer*(-qz_avg[::iskipLayers, row_cross_section, ::iskipCols]),
           color='w', scale=5, headwidth=3, headlength=2,
           headaxislength=2, width=0.0025)

# # # Recharge Scenario 1: Age

ax2 = fig.add_subplot(6, 1, 2)
ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img2 = ax2.imshow(np.flipud(raster), cmap=age_cmap, extent=extent, aspect=5, vmin = age_min, vmax = age_max) # 

cs = plt.contour(raster, levels=levels, extent=extent, colors=contour_colors) 
plt.clabel(cs, inline=1, fontsize=10, fmt='%1i', colors=contour_colors)

axes2 = plt.gca()
axes2.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes2.get_xaxis().set_visible(False)

# # # Recharge Scenario 1: Difference in Age (gamma)

ax3 = fig.add_subplot(6, 1, 3)
ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img3 = ax3.imshow(np.flipud(raster), cmap=diff_age_cmap, extent=extent, aspect=5, vmin = gamma_age_min, vmax = gamma_age_max) # 

cs = plt.contour(raster, levels=gamma_cs_labels, extent=extent, colors=contour_colors) 
plt.clabel(cs, gamma_cs_labels, inline=1, fontsize=10, fmt='%1i', colors=contour_colors)

axes3 = plt.gca()
axes3.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes3.get_xaxis().set_visible(False)

# # # Recharge Scenario 2: Head

rechargeScenario = 1
ax4 = fig.add_subplot(6, 1, 4)

qx_avg = np.empty(frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qx_avg[:, :, 1:] = 0.5 * (frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0:ncol-1] + 
                            frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 1:ncol])
qx_avg[:, :, 0] = 0.5 * frfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, :, 0]

qz_avg = np.empty(flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].shape, 
                  dtype=flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]].dtype)
qz_avg[1:, :, :] = 0.5 * (flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0:nlay-1, :, :] + 
                    flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][1:nlay, :, :])
qz_avg[0, :, :] = 0.5 * flfDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][0, :, :]

ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = headDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img4 = ax4.imshow(np.flipud(raster), cmap=head_cmap, extent=extent, aspect=5, vmin = head_min, vmax = head_max) # 
axes4 = plt.gca()
axes4.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes4.get_xaxis().set_visible(False)

y, x, z = nodeCoordsDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
X, Z = np.meshgrid(x, z[:, 0, 0])

plt.quiver(X[::iskipLayers, ::iskipCols], Z[::iskipLayers, ::iskipCols],
           colDisMultiplyer*qx_avg[::iskipLayers, row_cross_section, ::iskipCols], 
            layerDisMultiplyer*(-qz_avg[::iskipLayers, row_cross_section, ::iskipCols]),
           color='w', scale=5, headwidth=3, headlength=2,
           headaxislength=2, width=0.0025)

# # # Recharge Scenario 2: Age

ax5 = fig.add_subplot(6, 1, 5)
ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = ageDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img5 = ax5.imshow(np.flipud(raster), cmap=age_cmap, extent=extent, aspect=5, vmin = age_min, vmax = age_max) 

#print(get ready for manual contour labels)
cs = plt.contour(raster, levels=levels_2, extent=extent, colors=contour_colors) 
plt.clabel(cs, inline=1, manual=manual_plot, fontsize=10, fmt='%1i', colors=contour_colors)

axes5 = plt.gca()
axes5.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
axes5.get_xaxis().set_visible(False)

# # # Recharge Scenario 2: Gamma difference in age

ax6 = fig.add_subplot(6, 1, 6)
ml = modelObjectDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]]
mm = flopy.plot.crosssection.ModelCrossSection(model=ml, line={'row':row_cross_section})                
extent = (delr/2., Lx - delr/2., ztop - delc/2., delc/2.)  # values from model
raster = gammaAgeDict[rechargeScenarioNames[rechargeScenario]][caseStudyNames[caseStudy]][:, row_cross_section, :]
img6 = ax6.imshow(np.flipud(raster), cmap=diff_age_cmap, extent=extent, aspect=5, vmin = gamma_age_min, vmax = gamma_age_max) 

cs = plt.contour(raster, levels=gamma_cs_labels, extent=extent, colors=contour_colors) 
plt.clabel(cs, gamma_cs_labels, inline=1, fontsize=10, fmt='%1i', colors=contour_colors)

axes6 = plt.gca()
axes6.set_ylim([25, 275])
plt.ylabel('$z$ [m]')
plt.xlabel('$x$ [m]')

# Adding colour-bars

plt.subplots_adjust(bottom=0.2)

cbaxes1 = fig.add_axes([.1, 0.1, 0.24, 0.03]) 
cb1 = plt.colorbar(img1, cax = cbaxes1, orientation="horizontal")  
cb1.set_label('Hydraulic head [m]')
tick_locator = ticker.MaxNLocator(nbins = 5)
cb1.locator = tick_locator
cb1.update_ticks()

cbaxes2 = fig.add_axes([.38, 0.1, 0.24, 0.03]) 
cb2 = plt.colorbar(img2, cax = cbaxes2, orientation="horizontal")  
cb2.set_label('Age [y]')
cb2.locator = tick_locator
cb2.update_ticks()

cbaxes3 = fig.add_axes([0.66, 0.1, 0.24, 0.03]) 
cb3 = plt.colorbar(img3, cax = cbaxes3, orientation="horizontal")  
cb3.set_label(r'$\Gamma\mathrm{^a}$ [-]')
cb3.locator = tick_locator
cb3.update_ticks()

# Adding text to indicate which recharge scenario
#plt.gcf().text(0.92, (0.8), "Recharge 1", fontsize=14, rotation=90*3)        
#plt.gcf().text(0.92, (0.45), "Recharge 2", fontsize=14, rotation=90*3) 
bbox_props = {'facecolor':'white', 'alpha':0.75, 'lw':0}
axes1.text(7500, 200, (r"$\mu$ = %.0f, $\sigma$ = %.2f" % (mean_a, std_a)),
           bbox=bbox_props)
axes2.text(7500, 200, (r"$\mu$ = " + str(mean_b) + r", $\sigma$ = " +str(std_b)),
           bbox=bbox_props)
axes3.text(7500, 200, (r"$\mu$ = %.2f, $\sigma$ = %.2f" % (mean_c, std_c)),
           bbox=bbox_props)
axes4.text(7500, 200, (r"$\mu$ = %.0f, $\sigma$ = %.2f" % (mean_d, std_d)),
           bbox=bbox_props)
axes5.text(7500, 200, (r"$\mu$ = " + str(mean_e) + r", $\sigma$ = " +str(std_e)),
           bbox=bbox_props)
axes6.text(7500, 200, (r"$\mu$ = %.2f, $\sigma$ = %.2f" % (mean_f, std_f)),
           bbox=bbox_props)

# Add text to the plot to label the plots
pos1 = axes1.get_position() # shows x, y, width, height
pos2 = axes2.get_position()
pos3 = axes3.get_position()
pos4 = axes4.get_position()
pos5 = axes5.get_position()
pos6 = axes6.get_position()

# Use position values for the text, i.e. (x, (y + height), ...
gap_amount = .086
plt.gcf().text(0.125, (0.8095511474164927+gap_amount), "(a) Hydraulic head, Uniform recharge")
plt.gcf().text(0.125, (0.6895511474164927+gap_amount), "(b) Groundwater age, Uniform recharge")
plt.gcf().text(0.125, (0.5695511474164927+gap_amount), "(c) Groundwater age difference, Uniform recharge")
plt.gcf().text(0.125, (0.4495511474164927+gap_amount), "(d) Hydraulic head, Upgradient recharge")
plt.gcf().text(0.125, (0.3295511474164927+gap_amount), "(e) Groundwater age, Upgradient recharge")
plt.gcf().text(0.125, (0.20955114741649272+gap_amount), "(f) Groundwater age difference, Upgradient recharge")

# Saving the plot
name = "fig_7"
plt.savefig(os.path.join(figureDirectory, name), dpi = dpi_value)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)
# C:\Program Files\Anaconda3\lib\site-packages\flopy\plot\crosssection.py:859: PendingDeprecationWarning: ModelCrossSection will be replaced by PlotCrossSection(), Calling PlotCrossSection()
#   warnings.warn(err_msg, PendingDeprecationWarning)

# %% [markdown]
# # Running angled barrier models
#
# Here, I will just show the head and age plots so won't use the same dictionary-type set up as last time.

# %%
angles 
hk_arrays_angled 
ang_head_rstrs = []
ang_age_rstrs = []

t1 = time.time()

for angle_i in range(len(angles)):
    
    print("Starting run for angle: %2.2f" %angles[angle_i])

    hk_array_4 = hk_arrays_angled[angle_i]
    
    modelname, modelname_mt3d, mf = flow_model(1, 3)
    mt = transport_model(modelname, modelname_mt3d, mf)
    
    headobj = bf.HeadFile(modelname + '.hds')
    head_times = headobj.get_times()
    head_raster = headobj.get_data(totim=head_times[0])
    
    ang_head_rstrs.append(head_raster)
    
    directage_file = modelname_mt3d + str('.ucn') 
    ucnobjc_direct_age = flopy.utils.binaryfile.UcnFile(directage_file, precision = model_precision)
    age_times = ucnobjc_direct_age.get_times()
    age_raster = ucnobjc_direct_age.get_data(totim=age_times[0])
    
    ang_age_rstrs.append(age_raster)
    
print("Finished running all scenarios")
t2 = time.time()  
run_time = t2-t1      
print("Total run time: " + str(run_time) + "seconds")
# Out:
# Starting run for angle: 11.25
# Flow model name: TB_01_R1_CS3
# Transport model name: TB_01_mt3d_R1_CS3
# Discretisation module set up
# Setting up hk array for Case Study 3
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 2
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R1_CS3.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1165E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   4416.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4095E+06  [K,I,J]   12   63  107
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3159E+06  [K,I,J]   12   63  107
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2261E+06  [K,I,J]   12   64  107
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4171E+05  [K,I,J]   12   62  108
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3187E+06  [K,I,J]   12   58  105
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7435E+05  [K,I,J]   12   63  108
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1299E+06  [K,I,J]    1   74  113
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =   4720.      [K,I,J]   12   61  109
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.5740E+05  [K,I,J]   12   61  110
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1835E+06  [K,I,J]   12   61  109
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1474E+06  [K,I,J]   12   61  109
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.7804E+05  [K,I,J]   12   61  109
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.3701E+05  [K,I,J]   12   61  110
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.8222E+05  [K,I,J]   12   61  109
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1449E+05  [K,I,J]   12   72  114
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =   3109.      [K,I,J]   12   70  115
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =   633.8      [K,I,J]   12   71  116
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =   670.4      [K,I,J]   12   72  114
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =   382.1      [K,I,J]   12   70  115
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =   13.83      [K,I,J]   12   66  200
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =   23.49      [K,I,J]   12   70  192
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =   44.06      [K,I,J]   12   65  200
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.7520E-01  [K,I,J]   12   74  136
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =   7.735      [K,I,J]   12   74  142
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =   39.90      [K,I,J]   12   74  143
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =   6.317      [K,I,J]   12   73  148
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =   27.23      [K,I,J]   12   74  143
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =   2.013      [K,I,J]   12   73  154
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =   5.374      [K,I,J]   12   76  154
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =   2.891      [K,I,J]   12   75  159
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =   4.116      [K,I,J]   12   72  154
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =   3.206      [K,I,J]   12   76  152
#  Outer Iter.  1  Inner Iter. 35:  Max. DC =   11.48      [K,I,J]   12   75  156
#  Outer Iter.  1  Inner Iter. 36:  Max. DC =   12.13      [K,I,J]   12   75  156
#  Outer Iter.  1  Inner Iter. 37:  Max. DC =  0.4771      [K,I,J]   12   75  158
#  Outer Iter.  1  Inner Iter. 38:  Max. DC =   6.217      [K,I,J]   12   74  160
#  Outer Iter.  1  Inner Iter. 39:  Max. DC =   10.40      [K,I,J]   12   74  156
#  Outer Iter.  1  Inner Iter. 40:  Max. DC =   7.485      [K,I,J]   12   73  163
#  Outer Iter.  1  Inner Iter. 41:  Max. DC =   19.54      [K,I,J]   12   74  159
#  Outer Iter.  1  Inner Iter. 42:  Max. DC =   18.02      [K,I,J]   12   74  159
#  Outer Iter.  1  Inner Iter. 43:  Max. DC =   4.254      [K,I,J]   12   72  163
#  Outer Iter.  1  Inner Iter. 44:  Max. DC =   6.157      [K,I,J]   12   72  163
#  Outer Iter.  1  Inner Iter. 45:  Max. DC =   2.615      [K,I,J]   12   72  162
#  Outer Iter.  1  Inner Iter. 46:  Max. DC =  0.2524      [K,I,J]   12   72  163
#  Outer Iter.  1  Inner Iter. 47:  Max. DC =  0.9526      [K,I,J]   12   72  162
#  Outer Iter.  1  Inner Iter. 48:  Max. DC =  0.5317      [K,I,J]   12   71  163
#  Outer Iter.  1  Inner Iter. 49:  Max. DC =   1.498      [K,I,J]   12   71  166
#  Outer Iter.  1  Inner Iter. 50:  Max. DC =  0.3628      [K,I,J]   12   71  165
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.7295E-02  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.1922E-02  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.3621E-02  [K,I,J]   12   35    6
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.4363E-02  [K,I,J]   12   35    4
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.1354E-03  [K,I,J]   12   40    3
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.3144E-02  [K,I,J]   12   38    4
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.1206E-02  [K,I,J]   12   71  112
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.1358E-02  [K,I,J]   12   70  112
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.4586E-03  [K,I,J]   12   73  112
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.2352E-02  [K,I,J]   12   69  112
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.2264E-02  [K,I,J]   12   68  114
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.2259E-02  [K,I,J]   12   66  115
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.7214E-02  [K,I,J]   12   69  116
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.9030E-02  [K,I,J]   12   69  116
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.5646E-03  [K,I,J]   12   69  114
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.6795E-05  [K,I,J]   11   70  112
#  Outer Iter.  2  Inner Iter. 17:  Max. DC =  0.3537E-03  [K,I,J]   12   69  161
#  Outer Iter.  2  Inner Iter. 18:  Max. DC =  0.1605E-03  [K,I,J]    1   72  113
#  Outer Iter.  2  Inner Iter. 19:  Max. DC =  0.3548E-03  [K,I,J]   12   72  113
#  Outer Iter.  2  Inner Iter. 20:  Max. DC =  0.9900E-04  [K,I,J]   12   65  200
#  Outer Iter.  2  Inner Iter. 21:  Max. DC =  0.7069E-04  [K,I,J]   12   68  190
#  Outer Iter.  2  Inner Iter. 22:  Max. DC =  0.2760E-04  [K,I,J]   12   68  182
#  Outer Iter.  2  Inner Iter. 23:  Max. DC =  0.4596E-04  [K,I,J]   12   43  200
#  Outer Iter.  2  Inner Iter. 24:  Max. DC =  0.1371E-04  [K,I,J]   12   42  200
#  Outer Iter.  2  Inner Iter. 25:  Max. DC =  0.6378E-05  [K,I,J]   12   44  200
#  Outer Iter.  2  Inner Iter. 26:  Max. DC =  0.1013E-05  [K,I,J]   12   46  200
#  Outer Iter.  2  Inner Iter. 27:  Max. DC =  0.1371E-05  [K,I,J]   12   36  177
#  Outer Iter.  2  Inner Iter. 28:  Max. DC =  0.6557E-06  [K,I,J]   12   34  175
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.9933E-04  [K,I,J]   12    1    1
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.3615E-04  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.1594E-04  [K,I,J]   12   63    2
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.7778E-05  [K,I,J]   11   77  110
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.4643E-04  [K,I,J]   11   72  111
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.4339E-04  [K,I,J]   11   73  111
#  Outer Iter.  3  Inner Iter.  7:  Max. DC =  0.7242E-05  [K,I,J]   11   76  111
#  Outer Iter.  3  Inner Iter.  8:  Max. DC =  0.1234E-04  [K,I,J]   12   75  111
#  Outer Iter.  3  Inner Iter.  9:  Max. DC =  0.2080E-04  [K,I,J]   12   75  111
#  Outer Iter.  3  Inner Iter. 10:  Max. DC =  0.3815E-05  [K,I,J]   12   71  113
#  Outer Iter.  3  Inner Iter. 11:  Max. DC =  0.2712E-05  [K,I,J]   11   73  111
#  Outer Iter.  3  Inner Iter. 12:  Max. DC =  0.1222E-05  [K,I,J]    9   72  111
#  Outer Iter.  3  Inner Iter. 13:  Max. DC =  0.2161E-05  [K,I,J]    1   70  113
#  Outer Iter.  3  Inner Iter. 14:  Max. DC =  0.1693E-04  [K,I,J]   11   74  111
#  Outer Iter.  3  Inner Iter. 15:  Max. DC =  0.1401E-04  [K,I,J]   11   75  111
#  Outer Iter.  3  Inner Iter. 16:  Max. DC =  0.1192E-05  [K,I,J]   12   57  199
#  Outer Iter.  3  Inner Iter. 17:  Max. DC =  0.1669E-05  [K,I,J]   12   65  145
#  Outer Iter.  3  Inner Iter. 18:  Max. DC =  0.7153E-06  [K,I,J]   12   68  170
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.1848E-05  [K,I,J]   12   96    1
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.3040E-05  [K,I,J]   12   99    1
#  Outer Iter.  4  Inner Iter.  3:  Max. DC =  0.2563E-05  [K,I,J]   12   99    1
#  Outer Iter.  4  Inner Iter.  4:  Max. DC =  0.5960E-06  [K,I,J]    9   73  114
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.7153E-06  [K,I,J]   12   50  187
#
#  Program completed.   Total CPU time:  000 minutes  3.562 seconds
# Transport model has been run
# Starting run for angle: 22.50
# Flow model name: TB_01_R1_CS3
# Transport model name: TB_01_mt3d_R1_CS3
# Discretisation module set up
# Setting up hk array for Case Study 3
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 2
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R1_CS3.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1377E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   6734.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3009E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6153E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2726E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7218E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3800E+05  [K,I,J]   12   63  112
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1431E+05  [K,I,J]    3   75  121
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2991E+05  [K,I,J]   12   63  112
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5590E+06  [K,I,J]   12   62  114
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.4946E+06  [K,I,J]   12   62  114
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1186E+06  [K,I,J]   12   61  117
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.2135E+05  [K,I,J]   12   63  117
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1219E+05  [K,I,J]   12   61  116
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1737E+05  [K,I,J]   12   60  119
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =   3577.      [K,I,J]   12   56  139
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =   2289.      [K,I,J]   12   56  138
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =   1392.      [K,I,J]   12   55  144
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =   1457.      [K,I,J]   12   55  145
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =   940.3      [K,I,J]   12   54  150
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =   672.0      [K,I,J]   12   53  153
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =   511.1      [K,I,J]   12   54  150
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =   95.10      [K,I,J]   12   54  149
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =   33.42      [K,I,J]   12   70  163
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =   29.58      [K,I,J]   12   52  158
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =   18.07      [K,I,J]   12   71  149
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =   13.30      [K,I,J]   12   71  149
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =   1.271      [K,I,J]   12   70  151
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =   8.600      [K,I,J]   12   51  159
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =   9.282      [K,I,J]   12   51  158
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =   3.604      [K,I,J]   12   54  156
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =  0.9336      [K,I,J]   12   54  153
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =   2.152      [K,I,J]   12   54  157
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =  0.2939      [K,I,J]   12   66  175
#  Outer Iter.  1  Inner Iter. 35:  Max. DC =  0.1401      [K,I,J]   12   66  165
#  Outer Iter.  1  Inner Iter. 36:  Max. DC =  0.1216      [K,I,J]   12   67  168
#  Outer Iter.  1  Inner Iter. 37:  Max. DC =  0.9229E-01  [K,I,J]    6   66  170
#  Outer Iter.  1  Inner Iter. 38:  Max. DC =  0.1855E-01  [K,I,J]   12   52  156
#  Outer Iter.  1  Inner Iter. 39:  Max. DC =  0.2832E-01  [K,I,J]   12   48  200
#  Outer Iter.  1  Inner Iter. 40:  Max. DC =  0.2539E-01  [K,I,J]   12   70  168
#  Outer Iter.  1  Inner Iter. 41:  Max. DC =  0.1709E-01  [K,I,J]   12   70  166
#  Outer Iter.  1  Inner Iter. 42:  Max. DC =  0.1465E-02  [K,I,J]    2   70  161
#  Outer Iter.  1  Inner Iter. 43:  Max. DC =  0.1465E-02  [K,I,J]    5   70  167
#  Outer Iter.  1  Inner Iter. 44:  Max. DC =  0.1953E-02  [K,I,J]   12   45  200
#  Outer Iter.  1  Inner Iter. 45:  Max. DC =  0.4883E-03  [K,I,J]    1   64  195
#  Outer Iter.  1  Inner Iter. 46:  Max. DC =  0.2441E-03  [K,I,J]    1   68  169
#  Outer Iter.  1  Inner Iter. 47:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.8199E-02  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.3897E-02  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.2872      [K,I,J]   12   83    2
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.2808      [K,I,J]   12   83    2
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.9240E-02  [K,I,J]   12   38    6
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.7018E-02  [K,I,J]    1   63  112
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.1081E-01  [K,I,J]    1   63  112
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.1748E-01  [K,I,J]    1   62  114
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.1389E-01  [K,I,J]   12   38    9
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.6586E-02  [K,I,J]    1   70  119
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.5037E-02  [K,I,J]    1   61  117
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.6204E-02  [K,I,J]    1   70  119
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.1722E-02  [K,I,J]    1   63  111
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.7695E-03  [K,I,J]    1   68  121
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.4838E-03  [K,I,J]    1   65  123
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.6174E-03  [K,I,J]    1   69  121
#  Outer Iter.  2  Inner Iter. 17:  Max. DC =  0.8484E-03  [K,I,J]    1   67  121
#  Outer Iter.  2  Inner Iter. 18:  Max. DC =  0.1150E-02  [K,I,J]   12   57  139
#  Outer Iter.  2  Inner Iter. 19:  Max. DC =  0.4737E-03  [K,I,J]   12   57  136
#  Outer Iter.  2  Inner Iter. 20:  Max. DC =  0.6406E-03  [K,I,J]   12   57  140
#  Outer Iter.  2  Inner Iter. 21:  Max. DC =  0.2922E-03  [K,I,J]   12   56  141
#  Outer Iter.  2  Inner Iter. 22:  Max. DC =  0.6295E-03  [K,I,J]   12   56  142
#  Outer Iter.  2  Inner Iter. 23:  Max. DC =  0.8503E-03  [K,I,J]   12   54  153
#  Outer Iter.  2  Inner Iter. 24:  Max. DC =  0.4942E-03  [K,I,J]   12   54  151
#  Outer Iter.  2  Inner Iter. 25:  Max. DC =  0.2710E-02  [K,I,J]   12   54  149
#  Outer Iter.  2  Inner Iter. 26:  Max. DC =  0.2970E-02  [K,I,J]   12   54  149
#  Outer Iter.  2  Inner Iter. 27:  Max. DC =  0.4123E-03  [K,I,J]   12   55  144
#  Outer Iter.  2  Inner Iter. 28:  Max. DC =  0.5271E-03  [K,I,J]   12   52  159
#  Outer Iter.  2  Inner Iter. 29:  Max. DC =  0.3916E-04  [K,I,J]   12   52  156
#  Outer Iter.  2  Inner Iter. 30:  Max. DC =  0.2010E-03  [K,I,J]   12   53  156
#  Outer Iter.  2  Inner Iter. 31:  Max. DC =  0.1793E-02  [K,I,J]   12   54  156
#  Outer Iter.  2  Inner Iter. 32:  Max. DC =  0.1405E-03  [K,I,J]   12   52  170
#  Outer Iter.  2  Inner Iter. 33:  Max. DC =  0.1467E-02  [K,I,J]   12   54  157
#  Outer Iter.  2  Inner Iter. 34:  Max. DC =  0.5150E-04  [K,I,J]   12   69  168
#  Outer Iter.  2  Inner Iter. 35:  Max. DC =  0.1096E-03  [K,I,J]   12   69  164
#  Outer Iter.  2  Inner Iter. 36:  Max. DC =  0.6503E-04  [K,I,J]   11   69  147
#  Outer Iter.  2  Inner Iter. 37:  Max. DC =  0.6795E-05  [K,I,J]   12   69  150
#  Outer Iter.  2  Inner Iter. 38:  Max. DC =  0.3958E-04  [K,I,J]   12   70  155
#  Outer Iter.  2  Inner Iter. 39:  Max. DC =  0.2462E-04  [K,I,J]   12   69  150
#  Outer Iter.  2  Inner Iter. 40:  Max. DC =  0.4077E-04  [K,I,J]   12   68  156
#  Outer Iter.  2  Inner Iter. 41:  Max. DC =  0.2962E-04  [K,I,J]   12   68  158
#  Outer Iter.  2  Inner Iter. 42:  Max. DC =  0.2456E-04  [K,I,J]   11   68  153
#  Outer Iter.  2  Inner Iter. 43:  Max. DC =  0.1110E-03  [K,I,J]   12   68  160
#  Outer Iter.  2  Inner Iter. 44:  Max. DC =  0.2494E-03  [K,I,J]   12   68  157
#  Outer Iter.  2  Inner Iter. 45:  Max. DC =  0.2249E-03  [K,I,J]   11   68  156
#  Outer Iter.  2  Inner Iter. 46:  Max. DC =  0.1053E-03  [K,I,J]   12   68  158
#  Outer Iter.  2  Inner Iter. 47:  Max. DC =  0.8423E-03  [K,I,J]   12   69  153
#  Outer Iter.  2  Inner Iter. 48:  Max. DC =  0.6105E-03  [K,I,J]   12   69  152
#  Outer Iter.  2  Inner Iter. 49:  Max. DC =  0.2912E-03  [K,I,J]   12   69  153
#  Outer Iter.  2  Inner Iter. 50:  Max. DC =  0.1711E-04  [K,I,J]   12   69  162
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.7397E-04  [K,I,J]   12   96    1
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.6080E-05  [K,I,J]    2   67  168
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.1895E-04  [K,I,J]   12   72    3
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.2444E-05  [K,I,J]   12   96    1
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.1193E-03  [K,I,J]   12   50  153
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.2373E-03  [K,I,J]   11   65  118
#  Outer Iter.  3  Inner Iter.  7:  Max. DC =  0.3361E-03  [K,I,J]   11   65  118
#  Outer Iter.  3  Inner Iter.  8:  Max. DC =  0.3427E-04  [K,I,J]   12   49  191
#  Outer Iter.  3  Inner Iter.  9:  Max. DC =  0.2509E-04  [K,I,J]   12   48  200
#  Outer Iter.  3  Inner Iter. 10:  Max. DC =  0.2342E-04  [K,I,J]   12   48  200
#  Outer Iter.  3  Inner Iter. 11:  Max. DC =  0.1751E-03  [K,I,J]   12   49  167
#  Outer Iter.  3  Inner Iter. 12:  Max. DC =  0.2611E-03  [K,I,J]   12   49  172
#  Outer Iter.  3  Inner Iter. 13:  Max. DC =  0.7534E-04  [K,I,J]   12   49  192
#  Outer Iter.  3  Inner Iter. 14:  Max. DC =  0.6413E-04  [K,I,J]   12   49  173
#  Outer Iter.  3  Inner Iter. 15:  Max. DC =  0.1055E-04  [K,I,J]   12   50  166
#  Outer Iter.  3  Inner Iter. 16:  Max. DC =  0.7749E-06  [K,I,J]   10   65  191
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.2027E-05  [K,I,J]   12  100    1
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.5960E-07  [K,I,J]    1   64  194
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.1341E-05  [K,I,J]    7   65  178
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.2921E-05  [K,I,J]   12   64  185
#  Outer Iter.  5  Inner Iter.  3:  Max. DC =  0.1252E-05  [K,I,J]   11   78  152
#  Outer Iter.  5  Inner Iter.  4:  Max. DC =  0.1788E-06  [K,I,J]   11   76  157
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.1371E-05  [K,I,J]   12   62  196
#  Outer Iter.  6  Inner Iter.  2:  Max. DC =  0.4768E-06  [K,I,J]   11   75  160
#  Outer Iter.  7  Inner Iter.  1:  Max. DC =  0.1073E-05  [K,I,J]   12   61  198
#  Outer Iter.  7  Inner Iter.  2:  Max. DC =  0.1013E-05  [K,I,J]   12   75  141
#  Outer Iter.  7  Inner Iter.  3:  Max. DC =  0.9537E-06  [K,I,J]   12   74  146
#  Outer Iter.  8  Inner Iter.  1:  Max. DC =  0.1371E-05  [K,I,J]   12   75  139
#  Outer Iter.  8  Inner Iter.  2:  Max. DC =  0.9537E-06  [K,I,J]   12   74  144
#  Outer Iter.  9  Inner Iter.  1:  Max. DC =  0.7153E-06  [K,I,J]   12   73  147
#
#  Program completed.   Total CPU time:  000 minutes  4.422 seconds
# Transport model has been run
# Starting run for angle: 33.75
# Flow model name: TB_01_R1_CS3
# Transport model name: TB_01_mt3d_R1_CS3
# Discretisation module set up
# Setting up hk array for Case Study 3
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 2
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R1_CS3.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1534E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   8435.      [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2563E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1122E+06  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6901E+06  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5313E+06  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2501E+06  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1989E+06  [K,I,J]   12   66  124
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2058E+06  [K,I,J]   12   66  124
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2308E+05  [K,I,J]   12   66  129
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =   6617.      [K,I,J]   12   62  129
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1242E+05  [K,I,J]   12   61  132
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1645E+05  [K,I,J]   12   64  130
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1220E+06  [K,I,J]   12   60  135
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1189E+06  [K,I,J]   12   60  135
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2451E+05  [K,I,J]   12   60  134
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =   4782.      [K,I,J]   12   60  134
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1153E+05  [K,I,J]   12   60  136
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =   5565.      [K,I,J]   12   57  150
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =   1036.      [K,I,J]   12   55  159
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =   532.7      [K,I,J]   12   54  165
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =   359.4      [K,I,J]   12   55  157
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =   366.4      [K,I,J]   12   52  173
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =   41.08      [K,I,J]   12   51  180
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =   277.5      [K,I,J]   12   52  174
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =   27.07      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =   9.109      [K,I,J]   12   55  156
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =   39.50      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =   28.09      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =   9.151      [K,I,J]   12   52  175
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =   2.982      [K,I,J]   12   53  161
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =   2.578      [K,I,J]   12   51  175
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =   19.35      [K,I,J]   12   48  200
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =   17.38      [K,I,J]   12   48  200
#  Outer Iter.  1  Inner Iter. 35:  Max. DC =   2.299      [K,I,J]   12   51  177
#  Outer Iter.  1  Inner Iter. 36:  Max. DC =  0.4385      [K,I,J]   12   50  184
#  Outer Iter.  1  Inner Iter. 37:  Max. DC =  0.4854      [K,I,J]   12   51  178
#  Outer Iter.  1  Inner Iter. 38:  Max. DC =  0.5078E-01  [K,I,J]   12   51  172
#  Outer Iter.  1  Inner Iter. 39:  Max. DC =  0.8691E-01  [K,I,J]   12   52  166
#  Outer Iter.  1  Inner Iter. 40:  Max. DC =  0.3906E-02  [K,I,J]   10   49  184
#  Outer Iter.  1  Inner Iter. 41:  Max. DC =  0.2051E-01  [K,I,J]   12   51  181
#  Outer Iter.  1  Inner Iter. 42:  Max. DC =  0.8301E-01  [K,I,J]   12   51  183
#  Outer Iter.  1  Inner Iter. 43:  Max. DC =  0.1270E-01  [K,I,J]   12   49  185
#  Outer Iter.  1  Inner Iter. 44:  Max. DC =  0.2930E-02  [K,I,J]   10   49  184
#  Outer Iter.  1  Inner Iter. 45:  Max. DC =  0.1074E-01  [K,I,J]   12   50  175
#  Outer Iter.  1  Inner Iter. 46:  Max. DC =  0.6836E-02  [K,I,J]   12   49  187
#  Outer Iter.  1  Inner Iter. 47:  Max. DC =  0.4883E-02  [K,I,J]   12   49  193
#  Outer Iter.  1  Inner Iter. 48:  Max. DC =  0.6836E-02  [K,I,J]   12   53  178
#  Outer Iter.  1  Inner Iter. 49:  Max. DC =  0.4883E-03  [K,I,J]    1   49  182
#  Outer Iter.  1  Inner Iter. 50:  Max. DC =  0.5859E-02  [K,I,J]   12   51  185
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.8406E-02  [K,I,J]   12   99    1
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.1803E-01  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.1404E-01  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.2649E-03  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.7569E-02  [K,I,J]   12   66    5
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.5600E-02  [K,I,J]   12   60    5
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.2780E-01  [K,I,J]   11   66  119
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.3070E-01  [K,I,J]   12   71    4
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.3055E-02  [K,I,J]    1   68  119
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.2185E-01  [K,I,J]   12   68  119
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.2369E-01  [K,I,J]   12   68  119
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.1440E-01  [K,I,J]   12   59  142
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.1384E-01  [K,I,J]   12   59  142
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.8419E-03  [K,I,J]   12   61  136
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.9811E-03  [K,I,J]   10   59  142
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.4615E-03  [K,I,J]   12   57  149
#  Outer Iter.  2  Inner Iter. 17:  Max. DC =  0.1384E-02  [K,I,J]   12   57  150
#  Outer Iter.  2  Inner Iter. 18:  Max. DC =  0.5860E-03  [K,I,J]   10   54  174
#  Outer Iter.  2  Inner Iter. 19:  Max. DC =  0.3802E-03  [K,I,J]   12   54  168
#  Outer Iter.  2  Inner Iter. 20:  Max. DC =  0.5835E-04  [K,I,J]   12   53  170
#  Outer Iter.  2  Inner Iter. 21:  Max. DC =  0.1310E-03  [K,I,J]   12   53  185
#  Outer Iter.  2  Inner Iter. 22:  Max. DC =  0.4947E-05  [K,I,J]   12   54  164
#  Outer Iter.  2  Inner Iter. 23:  Max. DC =  0.4947E-04  [K,I,J]   12   55  154
#  Outer Iter.  2  Inner Iter. 24:  Max. DC =  0.1521E-03  [K,I,J]   12   48  200
#  Outer Iter.  2  Inner Iter. 25:  Max. DC =  0.6050E-04  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 26:  Max. DC =  0.9060E-05  [K,I,J]   12   48  200
#  Outer Iter.  2  Inner Iter. 27:  Max. DC =  0.1186E-04  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 28:  Max. DC =  0.7629E-05  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 29:  Max. DC =  0.3397E-05  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 30:  Max. DC =  0.3278E-05  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 31:  Max. DC =  0.1705E-04  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 32:  Max. DC =  0.6378E-05  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 33:  Max. DC =  0.8762E-05  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 34:  Max. DC =  0.1311E-05  [K,I,J]   12   46  200
#  Outer Iter.  2  Inner Iter. 35:  Max. DC =  0.6437E-05  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 36:  Max. DC =  0.3457E-05  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 37:  Max. DC =  0.4530E-05  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 38:  Max. DC =  0.2325E-05  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 39:  Max. DC =  0.1192E-06  [K,I,J]   12   44  198
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.1132E-03  [K,I,J]   12   98    1
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.4181E-04  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.2024E-04  [K,I,J]   12   94    2
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.4217E-04  [K,I,J]   12   77    3
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.2384E-06  [K,I,J]   11   69  117
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.3958E-04  [K,I,J]   11   69  117
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.2509E-04  [K,I,J]   11   69  117
#  Outer Iter.  4  Inner Iter.  3:  Max. DC =  0.2867E-04  [K,I,J]   11   65  130
#  Outer Iter.  4  Inner Iter.  4:  Max. DC =  0.2438E-04  [K,I,J]   11   65  129
#  Outer Iter.  4  Inner Iter.  5:  Max. DC =  0.8881E-05  [K,I,J]    3   61  137
#  Outer Iter.  4  Inner Iter.  6:  Max. DC =  0.6795E-05  [K,I,J]    9   65  131
#  Outer Iter.  4  Inner Iter.  7:  Max. DC =  0.5364E-06  [K,I,J]    1   59  146
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.5782E-05  [K,I,J]    3   59  145
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.4232E-05  [K,I,J]   11   62  137
#  Outer Iter.  5  Inner Iter.  3:  Max. DC =  0.1788E-06  [K,I,J]    3   57  158
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.2444E-05  [K,I,J]   11   61  140
#  Outer Iter.  6  Inner Iter.  2:  Max. DC =  0.1073E-05  [K,I,J]    7   57  153
#  Outer Iter.  6  Inner Iter.  3:  Max. DC =  0.8941E-06  [K,I,J]   12   63  134
#  Outer Iter.  7  Inner Iter.  1:  Max. DC =  0.1192E-05  [K,I,J]   12   64  130
#  Outer Iter.  7  Inner Iter.  2:  Max. DC =  0.1669E-05  [K,I,J]   12   63  134
#  Outer Iter.  7  Inner Iter.  3:  Max. DC =  0.7749E-06  [K,I,J]   12   60  153
#  Outer Iter.  8  Inner Iter.  1:  Max. DC =  0.1848E-05  [K,I,J]   12   60  152
#  Outer Iter.  8  Inner Iter.  2:  Max. DC =  0.2861E-05  [K,I,J]   12   59  155
#  Outer Iter.  8  Inner Iter.  3:  Max. DC =  0.8941E-06  [K,I,J]   12   58  167
#  Outer Iter.  9  Inner Iter.  1:  Max. DC =  0.1490E-05  [K,I,J]   12   58  169
#  Outer Iter.  9  Inner Iter.  2:  Max. DC =  0.1013E-05  [K,I,J]   12   57  199
#  Outer Iter.  9  Inner Iter.  3:  Max. DC =  0.1967E-05  [K,I,J]   12   57  199
#  Outer Iter.  9  Inner Iter.  4:  Max. DC =  0.1007E-04  [K,I,J]   12   57  199
#  Outer Iter.  9  Inner Iter.  5:  Max. DC =  0.9298E-05  [K,I,J]   12   57  199
#  Outer Iter.  9  Inner Iter.  6:  Max. DC =  0.1192E-05  [K,I,J]   12   48  188
#  Outer Iter.  9  Inner Iter.  7:  Max. DC =  0.4476E-04  [K,I,J]   12   74  170
#  Outer Iter.  9  Inner Iter.  8:  Max. DC =  0.4464E-04  [K,I,J]   12   74  170
#  Outer Iter.  9  Inner Iter.  9:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter. 10  Inner Iter.  1:  Max. DC =  0.8941E-06  [K,I,J]   12   56  194
#
#  Program completed.   Total CPU time:  000 minutes  4.406 seconds
# Transport model has been run
# Starting run for angle: 45.00
# Flow model name: TB_01_R1_CS3
# Transport model name: TB_01_mt3d_R1_CS3
# Discretisation module set up
# Setting up hk array for Case Study 3
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 2
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R1_CS3.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1668E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1018E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2504E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1712E+06  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1632E+06  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3619E+05  [K,I,J]    1   66  135
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3659E+05  [K,I,J]   12   66  134
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1662E+05  [K,I,J]    1   66  134
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =   8089.      [K,I,J]   12   67  134
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =   8763.      [K,I,J]   12   65  135
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =   8498.      [K,I,J]    8   65  135
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1249E+05  [K,I,J]   12   65  135
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =   9985.      [K,I,J]   12   65  135
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =   7050.      [K,I,J]   12   63  139
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =   6343.      [K,I,J]   12   59  155
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.3865E+05  [K,I,J]   12   62  145
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.3975E+05  [K,I,J]   12   62  145
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1883E+05  [K,I,J]   12   62  143
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1084E+05  [K,I,J]   12   62  143
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =   1364.      [K,I,J]   12   59  155
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =   1307.      [K,I,J]   12   59  154
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =   353.0      [K,I,J]   12   59  153
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =   568.0      [K,I,J]   12   59  155
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =   54.44      [K,I,J]   12   56  171
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =   113.7      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =   42.49      [K,I,J]   12   55  173
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =   6.812      [K,I,J]   12   55  167
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =   18.21      [K,I,J]   12   54  167
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =   12.54      [K,I,J]   12   59  163
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =   110.9      [K,I,J]   12   54  177
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =   103.8      [K,I,J]   12   54  177
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =   3.635      [K,I,J]   12   55  170
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =   3.898      [K,I,J]   12   55  168
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =  0.5566E-01  [K,I,J]   12   53  181
#  Outer Iter.  1  Inner Iter. 35:  Max. DC =  0.3535      [K,I,J]   12   53  182
#  Outer Iter.  1  Inner Iter. 36:  Max. DC =  0.7373      [K,I,J]   12   55  171
#  Outer Iter.  1  Inner Iter. 37:  Max. DC =   1.557      [K,I,J]   12   55  171
#  Outer Iter.  1  Inner Iter. 38:  Max. DC =  0.9863      [K,I,J]   12   55  173
#  Outer Iter.  1  Inner Iter. 39:  Max. DC =  0.1729      [K,I,J]   12   53  179
#  Outer Iter.  1  Inner Iter. 40:  Max. DC =  0.7227      [K,I,J]   12   53  184
#  Outer Iter.  1  Inner Iter. 41:  Max. DC =  0.7031      [K,I,J]   12   53  184
#  Outer Iter.  1  Inner Iter. 42:  Max. DC =  0.9082E-01  [K,I,J]   12   53  180
#  Outer Iter.  1  Inner Iter. 43:  Max. DC =  0.3906E-02  [K,I,J]   12   53  178
#  Outer Iter.  1  Inner Iter. 44:  Max. DC =  0.1953E-01  [K,I,J]   12   53  183
#  Outer Iter.  1  Inner Iter. 45:  Max. DC =  0.6836E-02  [K,I,J]   12   51  182
#  Outer Iter.  1  Inner Iter. 46:  Max. DC =  0.3906E-02  [K,I,J]   12   52  188
#  Outer Iter.  1  Inner Iter. 47:  Max. DC =  0.2930E-02  [K,I,J]   12   53  182
#  Outer Iter.  1  Inner Iter. 48:  Max. DC =  0.9766E-03  [K,I,J]   11   52  180
#  Outer Iter.  1  Inner Iter. 49:  Max. DC =  0.9766E-03  [K,I,J]    1   56  165
#  Outer Iter.  1  Inner Iter. 50:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.8915E-02  [K,I,J]   12   99    1
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.2455E-02  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.5722E-02  [K,I,J]   12   75    4
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.6074E-02  [K,I,J]   12   75    3
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.1532E-02  [K,I,J]   12   86    3
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.3427E-02  [K,I,J]   12   84    3
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.3601E-03  [K,I,J]   12   71    6
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.1175E-02  [K,I,J]   12   67    6
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.5988E-03  [K,I,J]   11   66  129
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.2759E-02  [K,I,J]   12   65  132
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.4463E-02  [K,I,J]   11   66  136
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.5804E-02  [K,I,J]   11   66  136
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.2523E-02  [K,I,J]   11   66  127
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.8015E-03  [K,I,J]   12   63  140
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.2605E-02  [K,I,J]   12   63  141
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.1132E-02  [K,I,J]   12   64  138
#  Outer Iter.  2  Inner Iter. 17:  Max. DC =  0.7045E-03  [K,I,J]   12   57  162
#  Outer Iter.  2  Inner Iter. 18:  Max. DC =  0.7114E-03  [K,I,J]   12   56  173
#  Outer Iter.  2  Inner Iter. 19:  Max. DC =  0.1047E-02  [K,I,J]   12   56  174
#  Outer Iter.  2  Inner Iter. 20:  Max. DC =  0.9982E-03  [K,I,J]   12   56  176
#  Outer Iter.  2  Inner Iter. 21:  Max. DC =  0.8388E-03  [K,I,J]   12   56  175
#  Outer Iter.  2  Inner Iter. 22:  Max. DC =  0.3272E-04  [K,I,J]   12   55  169
#  Outer Iter.  2  Inner Iter. 23:  Max. DC =  0.1256E-03  [K,I,J]   12   55  183
#  Outer Iter.  2  Inner Iter. 24:  Max. DC =  0.4768E-04  [K,I,J]   12   53  190
#  Outer Iter.  2  Inner Iter. 25:  Max. DC =  0.2390E-04  [K,I,J]   12   52  194
#  Outer Iter.  2  Inner Iter. 26:  Max. DC =  0.1097E-04  [K,I,J]   12   52  200
#  Outer Iter.  2  Inner Iter. 27:  Max. DC =  0.2551E-04  [K,I,J]   12   51  200
#  Outer Iter.  2  Inner Iter. 28:  Max. DC =  0.1830E-04  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter. 29:  Max. DC =  0.1502E-04  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter. 30:  Max. DC =  0.1311E-05  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter. 31:  Max. DC =  0.5901E-04  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter. 32:  Max. DC =  0.4959E-04  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter. 33:  Max. DC =  0.2062E-04  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter. 34:  Max. DC =  0.4470E-05  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter. 35:  Max. DC =  0.1431E-05  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter. 36:  Max. DC =  0.7153E-06  [K,I,J]   12   49  197
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.1175E-03  [K,I,J]   12   99    1
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.4712E-04  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.1892E-04  [K,I,J]   12   95    2
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.5603E-05  [K,I,J]   12   82    3
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.4113E-05  [K,I,J]   12   82    4
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.7153E-06  [K,I,J]   12   81    4
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.1270E-04  [K,I,J]   12   81    4
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.1156E-04  [K,I,J]   12   96    1
#  Outer Iter.  4  Inner Iter.  3:  Max. DC =  0.6616E-05  [K,I,J]   11   69  124
#  Outer Iter.  4  Inner Iter.  4:  Max. DC =  0.2623E-05  [K,I,J]   12   69  124
#  Outer Iter.  4  Inner Iter.  5:  Max. DC =  0.2205E-05  [K,I,J]    6   63  139
#  Outer Iter.  4  Inner Iter.  6:  Max. DC =  0.1329E-04  [K,I,J]   12   69  124
#  Outer Iter.  4  Inner Iter.  7:  Max. DC =  0.4113E-05  [K,I,J]   12   69  124
#  Outer Iter.  4  Inner Iter.  8:  Max. DC =  0.6020E-05  [K,I,J]   12   68  135
#  Outer Iter.  4  Inner Iter.  9:  Max. DC =  0.7331E-05  [K,I,J]   12   66  137
#  Outer Iter.  4  Inner Iter. 10:  Max. DC =  0.1192E-05  [K,I,J]   12   65  139
#  Outer Iter.  4  Inner Iter. 11:  Max. DC =  0.4470E-05  [K,I,J]   12   65  138
#  Outer Iter.  4  Inner Iter. 12:  Max. DC =  0.2146E-05  [K,I,J]   12   68  135
#  Outer Iter.  4  Inner Iter. 13:  Max. DC =  0.1431E-05  [K,I,J]   12   69  124
#  Outer Iter.  4  Inner Iter. 14:  Max. DC =  0.7749E-06  [K,I,J]   12   58  198
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.1550E-05  [K,I,J]   12   57  182
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.1252E-05  [K,I,J]   12   69  175
#  Outer Iter.  5  Inner Iter.  3:  Max. DC =  0.7749E-06  [K,I,J]    7   57  171
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.1013E-05  [K,I,J]   12   54  199
#  Outer Iter.  6  Inner Iter.  2:  Max. DC =  0.1311E-05  [K,I,J]   12   53  198
#  Outer Iter.  6  Inner Iter.  3:  Max. DC =  0.7749E-06  [K,I,J]   12   68  176
#  Outer Iter.  7  Inner Iter.  1:  Max. DC =  0.9537E-06  [K,I,J]   12   53  177
#
#  Program completed.   Total CPU time:  000 minutes  4.188 seconds
# Transport model has been run
# Starting run for angle: 56.25
# Flow model name: TB_01_R1_CS3
# Transport model name: TB_01_mt3d_R1_CS3
# Discretisation module set up
# Setting up hk array for Case Study 3
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 2
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R1_CS3.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1796E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1236E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2068E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4283E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4133E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1225E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =   3187.      [K,I,J]   12   63  140
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1051E+05  [K,I,J]   12  100    1
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4168E+05  [K,I,J]   12   63  139
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4145E+05  [K,I,J]   12   63  139
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.4734E+05  [K,I,J]   12   64  139
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.4291E+05  [K,I,J]   12   64  139
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1017E+05  [K,I,J]   12   61  143
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.3863E+05  [K,I,J]   12   59  168
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.3316E+05  [K,I,J]   12   59  169
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =   6551.      [K,I,J]   12   59  153
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =   2610.      [K,I,J]   12   57  166
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =   660.1      [K,I,J]   12   56  172
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =   1649.      [K,I,J]   12   55  172
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =   9152.      [K,I,J]   12   55  174
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =   9529.      [K,I,J]   12   55  173
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =   1269.      [K,I,J]   12   55  172
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =   215.1      [K,I,J]   12   56  166
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =   64.18      [K,I,J]   12   52  200
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =   24.00      [K,I,J]   12   52  183
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =   174.7      [K,I,J]   12   50  200
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =   37.07      [K,I,J]   12   54  188
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =   14.95      [K,I,J]   12   54  183
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =   3.613      [K,I,J]   12   53  177
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =   4.967      [K,I,J]   12   53  179
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =   1.023      [K,I,J]   12   52  186
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =  0.1865      [K,I,J]   12   51  193
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =  0.5205      [K,I,J]   12   52  181
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =  0.4180      [K,I,J]   12   55  175
#  Outer Iter.  1  Inner Iter. 35:  Max. DC =  0.7832      [K,I,J]   12   55  178
#  Outer Iter.  1  Inner Iter. 36:  Max. DC =  0.8086      [K,I,J]   12   53  183
#  Outer Iter.  1  Inner Iter. 37:  Max. DC =  0.9062      [K,I,J]   12   53  185
#  Outer Iter.  1  Inner Iter. 38:  Max. DC =  0.2510      [K,I,J]   12   53  178
#  Outer Iter.  1  Inner Iter. 39:  Max. DC =  0.1719      [K,I,J]   12   53  178
#  Outer Iter.  1  Inner Iter. 40:  Max. DC =   1.421      [K,I,J]   12   53  182
#  Outer Iter.  1  Inner Iter. 41:  Max. DC =   1.421      [K,I,J]   12   53  182
#  Outer Iter.  1  Inner Iter. 42:  Max. DC =  0.3223E-01  [K,I,J]   12   53  179
#  Outer Iter.  1  Inner Iter. 43:  Max. DC =  0.8301E-01  [K,I,J]   12   53  181
#  Outer Iter.  1  Inner Iter. 44:  Max. DC =  0.4590E-01  [K,I,J]   12   53  182
#  Outer Iter.  1  Inner Iter. 45:  Max. DC =  0.2539E-01  [K,I,J]   12   53  180
#  Outer Iter.  1  Inner Iter. 46:  Max. DC =  0.1270E-01  [K,I,J]   12   53  177
#  Outer Iter.  1  Inner Iter. 47:  Max. DC =  0.9766E-03  [K,I,J]    1   50  185
#  Outer Iter.  1  Inner Iter. 48:  Max. DC =  0.2246E-01  [K,I,J]   12   55  174
#  Outer Iter.  1  Inner Iter. 49:  Max. DC =  0.1055      [K,I,J]   12   55  177
#  Outer Iter.  1  Inner Iter. 50:  Max. DC =  0.9180E-01  [K,I,J]   12   53  176
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.8787E-02  [K,I,J]   12   99    1
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.2566E-02  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.8199E-02  [K,I,J]   12   76    4
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.7562E-02  [K,I,J]   12   79    4
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.4975E-03  [K,I,J]   12   87    3
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.2723E-02  [K,I,J]    3   67  131
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.2319E-02  [K,I,J]    2   67  131
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.8964E-03  [K,I,J]   12   89    3
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.2039E-02  [K,I,J]   12   88    3
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.8727E-03  [K,I,J]   12   65  133
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.1108E-02  [K,I,J]   12   67  131
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.1842E-04  [K,I,J]    7   59  154
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.1522E-03  [K,I,J]    7   59  155
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.3167E-03  [K,I,J]    7   57  164
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.1766E-02  [K,I,J]   12   57  162
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.7217E-03  [K,I,J]   12   57  159
#  Outer Iter.  2  Inner Iter. 17:  Max. DC =  0.5981E-03  [K,I,J]   12   56  177
#  Outer Iter.  2  Inner Iter. 18:  Max. DC =  0.1127E-03  [K,I,J]   12   55  186
#  Outer Iter.  2  Inner Iter. 19:  Max. DC =  0.2666E-03  [K,I,J]   12   59  158
# ...
#  Outer Iter.  2  Inner Iter. 17:  Max. DC =  0.3773E-03  [K,I,J]   12   53  172
#  Outer Iter.  2  Inner Iter. 18:  Max. DC =  0.3794E-03  [K,I,J]   12   52  181
#  Outer Iter.  2  Inner Iter. 19:  Max. DC =  0.2246E-03  [K,I,J]   12   55  177
#  Outer Iter.  2  Inner Iter. 20:  Max. DC =  0.1175E-03  [K,I,J]   12   50  192
#  Outer Iter.  2  Inner Iter. 21:  Max. DC =  0.4971E-04  [K,I,J]   12   51  180
#  Outer Iter.  2  Inner Iter. 22:  Max. DC =  0.1192E-04  [K,I,J]   12   51  177
#  Outer Iter.  2  Inner Iter. 23:  Max. DC =  0.1032E-03  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter. 24:  Max. DC =  0.4590E-05  [K,I,J]   12   54  182
#  Outer Iter.  2  Inner Iter. 25:  Max. DC =  0.1901E-04  [K,I,J]   12   48  200
#  Outer Iter.  2  Inner Iter. 26:  Max. DC =  0.2509E-04  [K,I,J]   12   48  200
#  Outer Iter.  2  Inner Iter. 27:  Max. DC =  0.2384E-05  [K,I,J]   12   48  200
#  Outer Iter.  2  Inner Iter. 28:  Max. DC =  0.3517E-05  [K,I,J]   12   48  200
#  Outer Iter.  2  Inner Iter. 29:  Max. DC =  0.1192E-06  [K,I,J]   12   51  200
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.1238E-03  [K,I,J]   12   99    1
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.4056E-04  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.1794E-04  [K,I,J]   12   95    2
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.7838E-05  [K,I,J]   12   82    3
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.7510E-05  [K,I,J]   12   88    3
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.1505E-04  [K,I,J]   12   87    3
#  Outer Iter.  3  Inner Iter.  7:  Max. DC =  0.3576E-05  [K,I,J]   11   59  142
#  Outer Iter.  3  Inner Iter.  8:  Max. DC =  0.1507E-03  [K,I,J]   12   86    3
#  Outer Iter.  3  Inner Iter.  9:  Max. DC =  0.4770E-03  [K,I,J]   12   79    2
#  Outer Iter.  3  Inner Iter. 10:  Max. DC =  0.3226E-03  [K,I,J]   12   80    2
#  Outer Iter.  3  Inner Iter. 11:  Max. DC =  0.2801E-05  [K,I,J]   12   54  171
#  Outer Iter.  3  Inner Iter. 12:  Max. DC =  0.2980E-06  [K,I,J]    2   53  182
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.3278E-05  [K,I,J]   11   54  163
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.2027E-05  [K,I,J]   11   53  172
#  Outer Iter.  4  Inner Iter.  3:  Max. DC =  0.2980E-06  [K,I,J]    8   52  174
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.1669E-05  [K,I,J]   11   53  192
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.1371E-05  [K,I,J]   10   51  184
#  Outer Iter.  5  Inner Iter.  3:  Max. DC =  0.1132E-05  [K,I,J]   12   51  173
#  Outer Iter.  5  Inner Iter.  4:  Max. DC =  0.2205E-05  [K,I,J]   12   51  172
#  Outer Iter.  5  Inner Iter.  5:  Max. DC =  0.5960E-06  [K,I,J]   11   51  176
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.9537E-06  [K,I,J]   12   82  184
#
#  Program completed.   Total CPU time:  000 minutes  3.734 seconds
# Transport model has been run
# Starting run for angle: 78.75
# Flow model name: TB_01_R1_CS3
# Transport model name: TB_01_mt3d_R1_CS3
# Discretisation module set up
# Setting up hk array for Case Study 3
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 2
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R1_CS3.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1913E+05  [K,I,J]   12   57  139
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   7195.      [K,I,J]   12   43   62
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2671E+05  [K,I,J]   12   99   10
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3254E+05  [K,I,J]   12   99    7
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5087E+05  [K,I,J]   12   99    9
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =   1251.      [K,I,J]   12   99    4
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =   1096.      [K,I,J]   12   52  149
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =   49.16      [K,I,J]   12   54  145
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =   1590.      [K,I,J]   12   53  167
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =   4439.      [K,I,J]   12   52  192
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =   1905.      [K,I,J]   12   52  185
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =   217.8      [K,I,J]   12   50  200
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =   140.5      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =   200.5      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =   82.37      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =   1.836      [K,I,J]   12   49  168
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.6846      [K,I,J]   12   49  168
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =   24.49      [K,I,J]   12   49  170
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =   3.307      [K,I,J]   12   52  195
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =   4.122      [K,I,J]   12   53  185
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =   17.31      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =   16.71      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =   13.43      [K,I,J]   12   52  200
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =   7.830      [K,I,J]   12   52  200
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =   4.597      [K,I,J]   12   52  196
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =   1.831      [K,I,J]   12   52  200
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.7930      [K,I,J]   12   52  193
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.4971      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =  0.2549      [K,I,J]   12   52  197
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =  0.5332      [K,I,J]   12   52  194
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =  0.2686      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =  0.8203E-01  [K,I,J]   12   51  199
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =  0.4668      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =   1.929      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter. 35:  Max. DC =   2.115      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter. 36:  Max. DC =  0.7812E-02  [K,I,J]   12   50  199
#  Outer Iter.  1  Inner Iter. 37:  Max. DC =  0.3809E-01  [K,I,J]   12   50  200
#  Outer Iter.  1  Inner Iter. 38:  Max. DC =  0.3223      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter. 39:  Max. DC =  0.1758E-01  [K,I,J]   12   47  169
#  Outer Iter.  1  Inner Iter. 40:  Max. DC =  0.1846      [K,I,J]   12   50  200
#  Outer Iter.  1  Inner Iter. 41:  Max. DC =  0.9766E-03  [K,I,J]    2   47  168
#  Outer Iter.  1  Inner Iter. 42:  Max. DC =  0.2002E-01  [K,I,J]   12   48  163
#  Outer Iter.  1  Inner Iter. 43:  Max. DC =  0.1123E-01  [K,I,J]   12   46  175
#  Outer Iter.  1  Inner Iter. 44:  Max. DC =  0.1855E-01  [K,I,J]   12   48  163
#  Outer Iter.  1  Inner Iter. 45:  Max. DC =  0.3320E-01  [K,I,J]   12   46  175
#  Outer Iter.  1  Inner Iter. 46:  Max. DC =  0.3027E-01  [K,I,J]   12   46  174
#  Outer Iter.  1  Inner Iter. 47:  Max. DC =  0.5859E-02  [K,I,J]   12   46  173
#  Outer Iter.  1  Inner Iter. 48:  Max. DC =  0.6348E-02  [K,I,J]   12   46  172
#  Outer Iter.  1  Inner Iter. 49:  Max. DC =  0.2441E-02  [K,I,J]   12   46  171
#  Outer Iter.  1  Inner Iter. 50:  Max. DC =  0.3369E-01  [K,I,J]   12   46  173
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.7726E-02  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.1460E-02  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.1698E-02  [K,I,J]   12   52    3
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.2914E-03  [K,I,J]   12   46   11
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.8362E-03  [K,I,J]   12   55  152
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.1298E-02  [K,I,J]   12   55  152
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.1952E-01  [K,I,J]   12   54  158
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.1972E-01  [K,I,J]   12   54  158
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.5326E-03  [K,I,J]   12   55  150
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.1777E-02  [K,I,J]   12   52  163
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.1384E-02  [K,I,J]   12   52  162
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.2959E-03  [K,I,J]   12   50  182
#  Outer Iter.  2  Inner Iter. 13:  Max. DC =  0.6106E-03  [K,I,J]   12   49  185
#  Outer Iter.  2  Inner Iter. 14:  Max. DC =  0.4544E-03  [K,I,J]   12   49  184
#  Outer Iter.  2  Inner Iter. 15:  Max. DC =  0.5126E-05  [K,I,J]   12   50  186
#  Outer Iter.  2  Inner Iter. 16:  Max. DC =  0.1957E-03  [K,I,J]   12   51  200
#  Outer Iter.  2  Inner Iter. 17:  Max. DC =  0.5710E-04  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 18:  Max. DC =  0.1067E-04  [K,I,J]   12   52  175
#  Outer Iter.  2  Inner Iter. 19:  Max. DC =  0.2801E-04  [K,I,J]   12   49  200
#  Outer Iter.  2  Inner Iter. 20:  Max. DC =  0.3278E-05  [K,I,J]   12   52  186
#  Outer Iter.  2  Inner Iter. 21:  Max. DC =  0.1729E-04  [K,I,J]   12   50  200
#  Outer Iter.  2  Inner Iter. 22:  Max. DC =  0.5364E-06  [K,I,J]   12   51  199
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.1098E-03  [K,I,J]   12   97    1
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.3138E-04  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.8255E-05  [K,I,J]   12   61    5
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.1061E-04  [K,I,J]   11   54  145
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.7063E-05  [K,I,J]    3   54  145
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.8941E-06  [K,I,J]    2   54  147
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.5186E-05  [K,I,J]   10   54  147
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.7153E-06  [K,I,J]    1   53  157
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.4888E-05  [K,I,J]    5   53  155
#  Outer Iter.  5  Inner Iter.  2:  Max. DC =  0.9537E-06  [K,I,J]    9   52  163
#  Outer Iter.  6  Inner Iter.  1:  Max. DC =  0.2980E-05  [K,I,J]    8   52  165
#  Outer Iter.  6  Inner Iter.  2:  Max. DC =  0.6557E-06  [K,I,J]   10   52  157
#  Outer Iter.  7  Inner Iter.  1:  Max. DC =  0.3517E-05  [K,I,J]   10   52  159
#  Outer Iter.  7  Inner Iter.  2:  Max. DC =  0.4172E-06  [K,I,J]   10   51  163
#  Outer Iter.  8  Inner Iter.  1:  Max. DC =  0.2384E-05  [K,I,J]   10   51  168
#  Outer Iter.  8  Inner Iter.  2:  Max. DC =  0.1550E-05  [K,I,J]   10   50  175
#  Outer Iter.  8  Inner Iter.  3:  Max. DC =  0.3099E-05  [K,I,J]   10   50  180
#  Outer Iter.  8  Inner Iter.  4:  Max. DC =  0.1371E-05  [K,I,J]   12   49  169
#  Outer Iter.  8  Inner Iter.  5:  Max. DC =  0.5960E-07  [K,I,J]    1   48  180
#  Outer Iter.  9  Inner Iter.  1:  Max. DC =  0.1669E-05  [K,I,J]   12   48  185
#  Outer Iter.  9  Inner Iter.  2:  Max. DC =  0.1550E-05  [K,I,J]   12   47  196
#  Outer Iter.  9  Inner Iter.  3:  Max. DC =  0.5960E-06  [K,I,J]    8   51  163
#  Outer Iter. 10  Inner Iter.  1:  Max. DC =  0.7749E-06  [K,I,J]   12   47  199
#
#  Program completed.   Total CPU time:  000 minutes  3.781 seconds
# Transport model has been run
# Starting run for angle: 90.00
# Flow model name: TB_01_R1_CS3
# Transport model name: TB_01_mt3d_R1_CS3
# Discretisation module set up
# Setting up hk array for Case Study 3
# Upstream weighting package set up
# Newton solver set up
# Setting up recharge array for Recharge Scenario 2
# Recharge package set up
# General head boundary package set up
# Output control package set up
# Basic package set up
# Link-Mass Transport package set up
# Input written
# END: Flow model has been run
# FloPy is using the following  executable to run the model: C:\Program Files\mt3d-usgs_Distribution\bin\MT3D-USGS_64.exe
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: TB_01_mt3d_R1_CS3.mtnam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:   1.000     Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2121E+05  [K,I,J]   12   51   89
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =   8523.      [K,I,J]    1   51   71
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2707E+05  [K,I,J]   12   99   21
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2469E+05  [K,I,J]   12   99   20
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =   404.1      [K,I,J]   12   49  200
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =   1980.      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =   494.2      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =   158.3      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =   94.48      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =   7.514      [K,I,J]   11   51  200
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =   1.617      [K,I,J]   12   51  200
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2051      [K,I,J]   11   43  200
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.7422E-01  [K,I,J]   12   51  133
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6934E-01  [K,I,J]   12   48  197
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.5176E-01  [K,I,J]   12   51   76
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1953E-02  [K,I,J]   12    1  190
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1953E-02  [K,I,J]   11   51  195
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.9766E-03  [K,I,J]   11    3  200
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.4883E-03  [K,I,J]   11   39  200
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  2  Inner Iter.  1:  Max. DC =  0.3749E-02  [K,I,J]   12  100    1
#  Outer Iter.  2  Inner Iter.  2:  Max. DC =  0.9498E-03  [K,I,J]   12   50   61
#  Outer Iter.  2  Inner Iter.  3:  Max. DC =  0.6925E-03  [K,I,J]   12   50   85
#  Outer Iter.  2  Inner Iter.  4:  Max. DC =  0.6267E-03  [K,I,J]   10   50   61
#  Outer Iter.  2  Inner Iter.  5:  Max. DC =  0.3237E-03  [K,I,J]   12   50   61
#  Outer Iter.  2  Inner Iter.  6:  Max. DC =  0.3654E-04  [K,I,J]   12   51  192
#  Outer Iter.  2  Inner Iter.  7:  Max. DC =  0.1802E-03  [K,I,J]   12   51  200
#  Outer Iter.  2  Inner Iter.  8:  Max. DC =  0.2325E-04  [K,I,J]   12   48  200
#  Outer Iter.  2  Inner Iter.  9:  Max. DC =  0.1800E-04  [K,I,J]   12   51  200
#  Outer Iter.  2  Inner Iter. 10:  Max. DC =  0.1013E-05  [K,I,J]   12   51  200
#  Outer Iter.  2  Inner Iter. 11:  Max. DC =  0.6676E-05  [K,I,J]   12   51  200
#  Outer Iter.  2  Inner Iter. 12:  Max. DC =  0.9537E-06  [K,I,J]   12   51  196
#  Outer Iter.  3  Inner Iter.  1:  Max. DC =  0.5132E-04  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  2:  Max. DC =  0.4917E-05  [K,I,J]   12  100    1
#  Outer Iter.  3  Inner Iter.  3:  Max. DC =  0.1907E-05  [K,I,J]   12   49   63
#  Outer Iter.  3  Inner Iter.  4:  Max. DC =  0.2384E-05  [K,I,J]   12   50  116
#  Outer Iter.  3  Inner Iter.  5:  Max. DC =  0.2116E-05  [K,I,J]   12   50   61
#  Outer Iter.  3  Inner Iter.  6:  Max. DC =  0.4768E-06  [K,I,J]   12   50   61
#  Outer Iter.  4  Inner Iter.  1:  Max. DC =  0.1162E-05  [K,I,J]   12   35    1
#  Outer Iter.  4  Inner Iter.  2:  Max. DC =  0.4172E-06  [K,I,J]   12    5  176
#  Outer Iter.  5  Inner Iter.  1:  Max. DC =  0.7153E-06  [K,I,J]   11   51  188
#
#  Program completed.   Total CPU time:  000 minutes  2.578 seconds
# Transport model has been run
# Finished running all scenarios
# Total run time: 144.62916541099548seconds

# %% [markdown]
# # Plotting hk arrays

# %% [markdown]
# ### First step - filtering, do I need this?

# %%
list_orientation_hks = hk_arrays_angled

list_max_values_orient = []
list_min_values_orient = []   
maxs_no_filter = []
mins_no_filter = []                     
                        
i = 0
for i in range(len(list_orientation_hks)):                   
    head_array_orient = ang_head_rstrs[i]
    hk_array_orient = list_orientation_hks[i] 
    
    list_max_values_orient.append(np.amax(head_array_orient[hk_array_orient>0.09]))
    list_min_values_orient.append(np.amin(head_array_orient[hk_array_orient>0.09]))
    
    maxs_no_filter.append(np.amax(head_array_orient))
    mins_no_filter.append(np.amin(head_array_orient))  

print("Max overall with filter is: %s" %(np.amax(list_max_values_orient)))
# Out:
# Max overall with filter is: 295.8627

# %% [markdown]
# ## First plot the head

# %%
fig = plt.figure(figsize=(10,12)) 

i = 0
for i in range(len(angles)):
    
    plt.subplot(4,2,(i+1))

    raster = ang_head_rstrs[i][nLayer, :, :]
    extent = (delr/2., Lx - delr/2., Ly - delc/2., delc/2.)

    img = plt.imshow(np.flipud(raster), cmap=head_cmap, extent=extent) 

    plt.ylabel('$y$ [m]')
    plt.xlabel('$x$ [m]')

    axes = plt.gca()

    if (i != 6 and i != 7):
        axes.axes.get_xaxis().set_visible(False)
    else:
        pass
    if (i == 1 or i == 3 or i == 5 or i == 7):
        axes.axes.get_yaxis().set_visible(False)
    else:
        pass
    
    axes.set_title('%2.2f degrees' %angles[i])


    cs = plt.contour(raster, antialiased = True, extent=extent, colors=contour_colors) 
    plt.clabel(cs, inline=1, fontsize=10, fmt='%1i', colors=contour_colors)

# %% [markdown]
# ## Then plot age

# %%
fig = plt.figure(figsize=(10,12)) 

i = 0
for i in range(len(angles)):
    
    plt.subplot(4,2,(i+1))

    raster = ang_age_rstrs[i][nLayer, :, :]
    extent = (delr/2., Lx - delr/2., Ly - delc/2., delc/2.)

    img = plt.imshow(np.flipud(raster), cmap=age_cmap, extent=extent) 

    plt.ylabel('$y$ [m]')
    plt.xlabel('$x$ [m]')

    axes = plt.gca()

    if (i != 6 and i != 7):
        axes.axes.get_xaxis().set_visible(False)
    else:
        pass
    if (i == 1 or i == 3 or i == 5 or i == 7):
        axes.axes.get_yaxis().set_visible(False)
    else:
        pass
    
    axes.set_title('%2.2f degrees' %angles[i])

    cs = plt.contour(raster, antialiased = True, extent=extent, colors=contour_colors) 
    plt.clabel(cs, inline=1, fontsize=10, fmt='%1i', colors=contour_colors)
